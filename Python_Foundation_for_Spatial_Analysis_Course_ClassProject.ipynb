# %% [markdown]
# ## <center>CLASS PROJECT FOR THE SPATIAL THOUGHTS<br> 'PYTHON FOUNDATION FOR SPATIAL ANALYSIS' COURSE</center>

# %% [markdown]
# <div style="text-align: justify">I recently moved to the city of Kolkata in West Bengal, India. When I started thinking of some idea for this project, the first thing that came to my mind was that I could use Python to get the locations of some of the most famous Durga Puja pandals of Kolkata, find an optimum route to visit all these places starting right from my home, and finally look for all restaurants located within 1 km of all these places I shall visit. And my Durga Puja plan for this year just got sorted! Thanks to Python's spatial analysis!</div>
#
# ***

# %% [markdown]
# First we shall import all the Python libraries we need for this project.

# %%
import pandas as pd
import geopandas as gpd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import folium
import requests
import os

# %% [markdown]
# ### Getting the coordinates and geometry of the places
#
# We shall geocode the places to visit, add my home location to the list and then get the geometry of all these places.

# %%
# Creating a list of Kolkata's Durga Puja locations to visit

places = ['Santosh Mitra Square', 
          'Bagbazar', 
          'College Square', 
          'Hindustan Park', 
          'Deshapriya Park', 
          'Ahiritola', 
          'Dum Dum Park', 
          'Lake Town', 
          'Manicktala', 
          'Ekdalia', 
          'Mudiali', 
          'Bosepukur', 
          'Naktala', 
          'Jodhpur Park']

# %%
# Creating a Pandas dataframe of the places
places_df = pd.DataFrame(places, columns = ['places'])
places_df
# Out:
#                   places
# 0   Santosh Mitra Square
# 1               Bagbazar
# 2         College Square
# 3         Hindustan Park
# 4        Deshapriya Park
# 5              Ahiritola
# 6           Dum Dum Park
# 7              Lake Town
# 8             Manicktala
# 9                Ekdalia
# 10               Mudiali
# 11             Bosepukur
# 12               Naktala
# 13          Jodhpur Park

# %%
# Using the Nominatim Geocoding Service from geopy library to geocode the places

# user_id = '<replace with your unique id>'

locator = Nominatim(user_agent=user_id)

# Function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=2)

# Applying the geocode function on our places dataframe
places_df['location'] = (places_df['places'] + ', Kolkata, West Bengal, India').apply(geocode)

places_df
# Out:
#                   places                                           location
# 0   Santosh Mitra Square  (Santosh Mitra Square, Chandi Chowk East, Kolk...
# 1               Bagbazar  (Bagbazar, Rabindra Sarani, Tiretta Bazaar, Ba...
# 2         College Square  (College Square Park, Tiretta Bazaar, Bow Baza...
# 3         Hindustan Park  (Hindustan Park, Manoharpukur, Kolkata, West B...
# 4        Deshapriya Park  (Deshapriya Park, Manoharpukur, Kolkata, West ...
# 5              Ahiritola  (Ahiritola Street, Shobha Bazar, Kolkata, West...
# 6           Dum Dum Park  (Dum Dum Children Park, Kolkata, Barrackpur - ...
# 7              Lake Town  (Lake town, Radha Gobinda Kar Road, Lake Town,...
# 8             Manicktala  (Frank Ross Pharmacy, P-14, CIT Rd, Manicktala...
# 9                Ekdalia  (Ekdalia, Rash Behari Avenue Connector, Kushit...
# 10               Mudiali  (Mudiali Club, SR Das Road, Kalighat, Kolkata,...
# 11             Bosepukur  (Bosepukur Shitalamandir, Rash Behari Avenue C...
# 12               Naktala  (Naktala, Netaji Subhash Chandra Bose Road, Sh...
# 13          Jodhpur Park  (Jodhpur Park, Kolkata, West Bengal, 700068, I...

# %%
# Extracting coordinates of the places and creating columns for latitude and longitude values
places_df['latitude'] = places_df['location'].apply(lambda loc: loc.latitude)
places_df['longitude'] = places_df['location'].apply(lambda loc: loc.longitude)

# Removing the 'location' column from the places dataframe
places_df = places_df.drop('location', axis = 1)

places_df
# Out:
#                   places   latitude  longitude
# 0   Santosh Mitra Square  22.565862  88.365558
# 1               Bagbazar  22.605210  88.365204
# 2         College Square  22.574653  88.363905
# 3         Hindustan Park  22.518370  88.361186
# 4        Deshapriya Park  22.518435  88.353515
# 5              Ahiritola  22.595334  88.355472
# 6           Dum Dum Park  22.621099  88.397826
# 7              Lake Town  22.609751  88.402644
# 8             Manicktala  22.581753  88.390794
# 9                Ekdalia  22.521226  88.369451
# 10               Mudiali  22.510081  88.346449
# 11             Bosepukur  22.519250  88.385210
# 12               Naktala  22.473870  88.361968
# 13          Jodhpur Park  22.505606  88.363674

# %%
# Coordinates of my home
home_coordinates = (22.707052, 88.463047)

# %%
# Creating a Pandas dataframe of just my home location

my_home = pd.DataFrame({'places':'My Home', 
                        'latitude':home_coordinates[0], 
                        'longitude':home_coordinates[1]}, 
                       columns=['places', 'latitude', 'longitude'], 
                       index=[0])

my_home
# Out:
#     places   latitude  longitude
# 0  My Home  22.707052  88.463047

# %%
# Adding my home location to the places dataframe
places_df_concat = pd.concat([my_home, places_df]).reset_index(drop=True)
places_df_concat
# Out:
#                   places   latitude  longitude
# 0                My Home  22.707052  88.463047
# 1   Santosh Mitra Square  22.565862  88.365558
# 2               Bagbazar  22.605210  88.365204
# 3         College Square  22.574653  88.363905
# 4         Hindustan Park  22.518370  88.361186
# 5        Deshapriya Park  22.518435  88.353515
# 6              Ahiritola  22.595334  88.355472
# 7           Dum Dum Park  22.621099  88.397826
# 8              Lake Town  22.609751  88.402644
# 9             Manicktala  22.581753  88.390794
# 10               Ekdalia  22.521226  88.369451
# 11               Mudiali  22.510081  88.346449
# 12             Bosepukur  22.519250  88.385210
# 13               Naktala  22.473870  88.361968
# 14          Jodhpur Park  22.505606  88.363674

# %%
# Creating a GeoPandas geodataframe of the places

# Getting the geometry of the locations 
geometry = gpd.points_from_xy(places_df_concat.longitude, places_df_concat.latitude)

# Projecting directly to WGS 84 UTM Zone 45N which covers West Bengal
places_gdf = gpd.GeoDataFrame(places_df_concat, crs='EPSG:32645', geometry=geometry)

places_gdf
# Out:
#                   places   latitude  longitude               geometry
# 0                My Home  22.707052  88.463047  POINT (88.463 22.707)
# 1   Santosh Mitra Square  22.565862  88.365558  POINT (88.366 22.566)
# 2               Bagbazar  22.605210  88.365204  POINT (88.365 22.605)
# 3         College Square  22.574653  88.363905  POINT (88.364 22.575)
# 4         Hindustan Park  22.518370  88.361186  POINT (88.361 22.518)
# 5        Deshapriya Park  22.518435  88.353515  POINT (88.354 22.518)
# 6              Ahiritola  22.595334  88.355472  POINT (88.355 22.595)
# 7           Dum Dum Park  22.621099  88.397826  POINT (88.398 22.621)
# 8              Lake Town  22.609751  88.402644  POINT (88.403 22.610)
# 9             Manicktala  22.581753  88.390794  POINT (88.391 22.582)
# 10               Ekdalia  22.521226  88.369451  POINT (88.369 22.521)
# 11               Mudiali  22.510081  88.346449  POINT (88.346 22.510)
# 12             Bosepukur  22.519250  88.385210  POINT (88.385 22.519)
# 13               Naktala  22.473870  88.361968  POINT (88.362 22.474)
# 14          Jodhpur Park  22.505606  88.363674  POINT (88.364 22.506)

# %% [markdown]
# ### Mapping the places
#
# Now, we shall visualize our places on a map using the Folium library.

# %%
# Getting the central coordinates to position the basemap
x_avg = places_gdf.centroid.x.mean()
y_avg = places_gdf.centroid.y.mean()

y_avg, x_avg
# Out:
# (22.561836789999997, 88.37639351186236)

# %%
# Creating the basemap 
kolkata_map = folium.Map(location=[y_avg, x_avg], tiles='CartoDB positron', zoom_start=11)

# %%
# Getting the places geodataframe's first row that contains my home location 
home = places_gdf.iloc[0]

# Adding my home location to the map with a red home-icon marker
folium.Marker(location=[home.latitude, home.longitude], 
              popup=home.places, 
              icon=folium.Icon(color='red', icon='home')).add_to(kolkata_map)

# Adding the rest of the places to the map, each with a blue map-marker
places_gdf.iloc[1:].apply(lambda place:folium.Marker(location=[place['latitude'], place['longitude']], 
                                                     popup=place['places'], 
                                                     icon=folium.Icon(color='blue', icon='map-marker')
                                                    ).add_to(kolkata_map), axis=1)

kolkata_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a91bff6d9e1e15e07478ce0028690e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a91bff6d9e1e15e07478ce0028690e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8a91bff6d9e1e15e07478ce0028690e3 = L.map(
#                 &quot;map_8a91bff6d9e1e15e07478ce0028690e3&quot;,
#                 {
#                     center: [22.561836789999997, 88.37639351186236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7297f3e5daf85bfb6281e0ec687743f4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var marker_81051bb35ed3c78a78a5ebcec0e301eb = L.marker(
#                 [22.707052, 88.463047],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_0479e744cf31955635e610d9c2939323 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81051bb35ed3c78a78a5ebcec0e301eb.setIcon(icon_0479e744cf31955635e610d9c2939323);
#
#
#         var popup_8c0691e27ac5a62c53426be005d0bf26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3009b02877d8f2beed01442eaa03655 = $(`&lt;div id=&quot;html_f3009b02877d8f2beed01442eaa03655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Home&lt;/div&gt;`)[0];
#             popup_8c0691e27ac5a62c53426be005d0bf26.setContent(html_f3009b02877d8f2beed01442eaa03655);
#
#
#         marker_81051bb35ed3c78a78a5ebcec0e301eb.bindPopup(popup_8c0691e27ac5a62c53426be005d0bf26)
#         ;
#
#
#
#
#             var marker_65030b681c7bad782ef367c1684b2845 = L.marker(
#                 [22.5658619, 88.36555761435561],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_3612ae3275b2f194b62b87e187e71b68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_65030b681c7bad782ef367c1684b2845.setIcon(icon_3612ae3275b2f194b62b87e187e71b68);
#
#
#         var popup_1d365cb7b18493be7bccd19538f1b1d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_16bde4e0197f948e4410427b3085832a = $(`&lt;div id=&quot;html_16bde4e0197f948e4410427b3085832a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santosh Mitra Square&lt;/div&gt;`)[0];
#             popup_1d365cb7b18493be7bccd19538f1b1d4.setContent(html_16bde4e0197f948e4410427b3085832a);
#
#
#         marker_65030b681c7bad782ef367c1684b2845.bindPopup(popup_1d365cb7b18493be7bccd19538f1b1d4)
#         ;
#
#
#
#
#             var marker_03285b6ad88884a73f4db47d0f6c1a81 = L.marker(
#                 [22.6052096, 88.3652044],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_6cc366d529c604c324a2c12d09f02b24 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_03285b6ad88884a73f4db47d0f6c1a81.setIcon(icon_6cc366d529c604c324a2c12d09f02b24);
#
#
#         var popup_de530c42481a2019b057c3185ddabc1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f5fb96c98c2601774f55a4d614ec56ae = $(`&lt;div id=&quot;html_f5fb96c98c2601774f55a4d614ec56ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bagbazar&lt;/div&gt;`)[0];
#             popup_de530c42481a2019b057c3185ddabc1f.setContent(html_f5fb96c98c2601774f55a4d614ec56ae);
#
#
#         marker_03285b6ad88884a73f4db47d0f6c1a81.bindPopup(popup_de530c42481a2019b057c3185ddabc1f)
#         ;
#
#
#
#
#             var marker_00ad71acc71b56ec6acdb90957b1c46b = L.marker(
#                 [22.57465335, 88.36390478535333],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_d85e4f571c1ac80ad4a3ea1ec5994bb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;

# %% [markdown]
# ### Finding and mapping the optimum route to visit the places
#
# Next, we shall use the Optimization service of the OpenRouteService API to get the optimum route to travel from my home to the Durga Puja locations in the city, and then visualize the route on our Kolkata map.

# %%
# It is clearly visible on the map that geographically 'Naktala' is the farthest location from my house. 
# Hence, we shall consider it the endpoint of our optimum route.

# Getting the row of 'Naktala' from the places geodataframe
endpoint = places_gdf.iloc[13]
endpoint
# Out:
# places                             Naktala
# latitude                          22.47387
# longitude                        88.361968
# geometry     POINT (88.3619683 22.4738701)
# Name: 13, dtype: object

# %%
# And my home location will be the starting point of our optimum route.

home
# Out:
# places                           My Home
# latitude                       22.707052
# longitude                      88.463047
# geometry     POINT (88.463047 22.707052)
# Name: 0, dtype: object

# %%
# Creating the vehicles and jobs parameters for the Optimization API call


# Vehicle to travel
vehicle = [{"id":1,
            "profile":"driving-car",
            "start":[home.longitude, home.latitude],
            "end":[endpoint.longitude, endpoint.latitude]}]


# Places to visit
jobs = []
# For loop to append the places from index 1 to 12, excluding the start('My Home') and end('Naktala') points
for i in range(1,13):
    place_dict = {}
    place = places_gdf.iloc[i]
    place_dict['id'] = i
    place_dict['location'] = [place.longitude, place.latitude]
    jobs.append(place_dict)
    
# Appending the remaining location which is at the last index position of the places geodataframe
last_row = places_gdf.iloc[-1]
jobs.append({'id':13, 'location':[last_row.longitude, last_row.latitude]})

# %%
vehicle
# Out:
# [{'id': 1,
#   'profile': 'driving-car',
#   'start': [88.463047, 22.707052],
#   'end': [88.3619683, 22.4738701]}]

# %%
jobs
# Out:
# [{'id': 1, 'location': [88.36555761435561, 22.5658619]},
#  {'id': 2, 'location': [88.3652044, 22.6052096]},
#  {'id': 3, 'location': [88.36390478535333, 22.57465335]},
#  {'id': 4, 'location': [88.3611863, 22.5183697]},
#  {'id': 5, 'location': [88.35351524759007, 22.5184354]},
#  {'id': 6, 'location': [88.3554724, 22.595334]},
#  {'id': 7, 'location': [88.39782553063668, 22.6210988]},
#  {'id': 8, 'location': [88.4026439, 22.6097509]},
#  {'id': 9, 'location': [88.3907936, 22.5817532]},
#  {'id': 10, 'location': [88.3694508, 22.521226]},
#  {'id': 11, 'location': [88.3464486, 22.5100811]},
#  {'id': 12, 'location': [88.3852102, 22.5192503]},
#  {'id': 13, 'location': [88.363674, 22.5056055]}]

# %%
# Using the Optimization service of the OpenRouteService API 

# ORS_API_KEY = '<replace with your unique ORS API key>'

body = {'jobs':jobs, 'vehicles':vehicle}

headers = {'Accept':'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8', 
           'Authorization':ORS_API_KEY, 
           'Content-Type':'application/json; charset=utf-8'}

# Using the requests library to make the API call
response = requests.post('https://api.openrouteservice.org/optimization', json=body, headers=headers)


# Getting the response in json format if the API request is successful 
if response.status_code == 200:
    print('Request successful.')
    optimization_data = response.json()
else:
    print('Request failed.')
# Out:
# Request successful.

# %%
optimization_data
# Out:
# {'code': 0,
#  'summary': {'cost': 5082,
#   'unassigned': 0,
#   'service': 0,
#   'duration': 5082,
#   'waiting_time': 0,
#   'computing_times': {'loading': 83, 'solving': 1}},
#  'unassigned': [],
#  'routes': [{'vehicle': 1,
#    'cost': 5082,
#    'service': 0,
#    'duration': 5082,
#    'waiting_time': 0,
#    'steps': [{'type': 'start',
#      'location': [88.463047, 22.707052],
#      'arrival': 0,
#      'duration': 0},
#     {'type': 'job',
#      'location': [88.39782553063668, 22.6210988],
#      'id': 7,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 7,
#      'arrival': 1155,
#      'duration': 1155},
#     {'type': 'job',
#      'location': [88.4026439, 22.6097509],
#      'id': 8,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 8,
#      'arrival': 1429,
#      'duration': 1429},
#     {'type': 'job',
#      'location': [88.3907936, 22.5817532],
#      'id': 9,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 9,
#      'arrival': 1834,
#      'duration': 1834},
#     {'type': 'job',
#      'location': [88.3652044, 22.6052096],
#      'id': 2,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 2,
#      'arrival': 2216,
#      'duration': 2216},
#     {'type': 'job',
#      'location': [88.3554724, 22.595334],
#      'id': 6,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 6,
#      'arrival': 2381,
#      'duration': 2381},
#     {'type': 'job',
#      'location': [88.36390478535333, 22.57465335],
#      'id': 3,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 3,
#      'arrival': 2611,
#      'duration': 2611},
#     {'type': 'job',
#      'location': [88.36555761435561, 22.5658619],
#      'id': 1,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 1,
#      'arrival': 2730,
#      'duration': 2730},
#     {'type': 'job',
#      'location': [88.3694508, 22.521226],
#      'id': 10,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 10,
#      'arrival': 3355,
#      'duration': 3355},
#     {'type': 'job',
#      'location': [88.3852102, 22.5192503],
#      'id': 12,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 12,
#      'arrival': 3626,
#      'duration': 3626},
#     {'type': 'job',
#      'location': [88.3611863, 22.5183697],
#      'id': 4,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 4,
#      'arrival': 3907,
#      'duration': 3907},
#     {'type': 'job',
#      'location': [88.35351524759007, 22.5184354],
#      'id': 5,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 5,
#      'arrival': 4021,
#      'duration': 4021},
#     {'type': 'job',
#      'location': [88.3464486, 22.5100811],
#      'id': 11,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 11,
#      'arrival': 4225,
#      'duration': 4225},
#     {'type': 'job',
#      'location': [88.363674, 22.5056055],
#      'id': 13,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 13,
#      'arrival': 4586,
#      'duration': 4586},
#     {'type': 'end',
#      'location': [88.3619683, 22.4738701],
#      'arrival': 5082,
#      'duration': 5082}]}]}

# %%
# Creating a list of coordinates of the locations on the optimum route

optimum_route_points = []

steps = optimization_data['routes'][0]['steps']

for step in steps:
    optimum_route_points.append((step['location'][1], step['location'][0]))
    
optimum_route_points
# Out:
# [(22.707052, 88.463047),
#  (22.6210988, 88.39782553063668),
#  (22.6097509, 88.4026439),
#  (22.5817532, 88.3907936),
#  (22.6052096, 88.3652044),
#  (22.595334, 88.3554724),
#  (22.57465335, 88.36390478535333),
#  (22.5658619, 88.36555761435561),
#  (22.521226, 88.3694508),
#  (22.5192503, 88.3852102),
#  (22.5183697, 88.3611863),
#  (22.5184354, 88.35351524759007),
#  (22.5100811, 88.3464486),
#  (22.5056055, 88.363674),
#  (22.4738701, 88.3619683)]

# %%
# Adding the optimum route as a polyline geometry feature to the Kolkata map
folium.PolyLine(optimum_route_points, color='red', weight=1.5, opacity=2).add_to(kolkata_map)

kolkata_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a91bff6d9e1e15e07478ce0028690e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a91bff6d9e1e15e07478ce0028690e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8a91bff6d9e1e15e07478ce0028690e3 = L.map(
#                 &quot;map_8a91bff6d9e1e15e07478ce0028690e3&quot;,
#                 {
#                     center: [22.561836789999997, 88.37639351186236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7297f3e5daf85bfb6281e0ec687743f4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var marker_81051bb35ed3c78a78a5ebcec0e301eb = L.marker(
#                 [22.707052, 88.463047],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_0479e744cf31955635e610d9c2939323 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81051bb35ed3c78a78a5ebcec0e301eb.setIcon(icon_0479e744cf31955635e610d9c2939323);
#
#
#         var popup_8c0691e27ac5a62c53426be005d0bf26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3009b02877d8f2beed01442eaa03655 = $(`&lt;div id=&quot;html_f3009b02877d8f2beed01442eaa03655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Home&lt;/div&gt;`)[0];
#             popup_8c0691e27ac5a62c53426be005d0bf26.setContent(html_f3009b02877d8f2beed01442eaa03655);
#
#
#         marker_81051bb35ed3c78a78a5ebcec0e301eb.bindPopup(popup_8c0691e27ac5a62c53426be005d0bf26)
#         ;
#
#
#
#
#             var marker_65030b681c7bad782ef367c1684b2845 = L.marker(
#                 [22.5658619, 88.36555761435561],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_3612ae3275b2f194b62b87e187e71b68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_65030b681c7bad782ef367c1684b2845.setIcon(icon_3612ae3275b2f194b62b87e187e71b68);
#
#
#         var popup_1d365cb7b18493be7bccd19538f1b1d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_16bde4e0197f948e4410427b3085832a = $(`&lt;div id=&quot;html_16bde4e0197f948e4410427b3085832a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santosh Mitra Square&lt;/div&gt;`)[0];
#             popup_1d365cb7b18493be7bccd19538f1b1d4.setContent(html_16bde4e0197f948e4410427b3085832a);
#
#
#         marker_65030b681c7bad782ef367c1684b2845.bindPopup(popup_1d365cb7b18493be7bccd19538f1b1d4)
#         ;
#
#
#
#
#             var marker_03285b6ad88884a73f4db47d0f6c1a81 = L.marker(
#                 [22.6052096, 88.3652044],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_6cc366d529c604c324a2c12d09f02b24 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_03285b6ad88884a73f4db47d0f6c1a81.setIcon(icon_6cc366d529c604c324a2c12d09f02b24);
#
#
#         var popup_de530c42481a2019b057c3185ddabc1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f5fb96c98c2601774f55a4d614ec56ae = $(`&lt;div id=&quot;html_f5fb96c98c2601774f55a4d614ec56ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bagbazar&lt;/div&gt;`)[0];
#             popup_de530c42481a2019b057c3185ddabc1f.setContent(html_f5fb96c98c2601774f55a4d614ec56ae);
#
#
#         marker_03285b6ad88884a73f4db47d0f6c1a81.bindPopup(popup_de530c42481a2019b057c3185ddabc1f)
#         ;
#
#
#
#
#             var marker_00ad71acc71b56ec6acdb90957b1c46b = L.marker(
#                 [22.57465335, 88.36390478535333],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_d85e4f571c1ac80ad4a3ea1ec5994bb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;

# %% [markdown]
# ### Finding all restaurants located within 1 km of each place to visit
#
# Now, we shall create buffers of 1 km around each place to visit, merge all the buffers into a single polygon feature to get rid of intersecting buffer polygons, load an OpenStreetMap geopackage file containing a points layer of restaurants in Kolkata, and extract only those restaurants which fall within the merged buffer polygon.

# %%
# Creating a GeoPandas geoseries of buffers of 1 km around the places to visit
buffer_1km = places_gdf['geometry'][1:].buffer(0.01)

# %%
# Creating a new map to visualize the buffers
buffer_map = folium.Map(location=[y_avg, x_avg], tiles='CartoDB positron', zoom_start=11)

# %%
# Converting the buffers geoseries into a geojson object to add to the map

buffer_geojson = buffer_1km.to_json()
buffer_geojson = folium.GeoJson(data=buffer_geojson)
buffer_geojson.add_to(buffer_map)

buffer_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29b9cca87a126e52052a08a2e75ffedc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29b9cca87a126e52052a08a2e75ffedc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_29b9cca87a126e52052a08a2e75ffedc = L.map(
#                 &quot;map_29b9cca87a126e52052a08a2e75ffedc&quot;,
#                 {
#                     center: [22.561836789999997, 88.37639351186236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2a1e8f193352cd41af0591104690047 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_29b9cca87a126e52052a08a2e75ffedc);
#
#
#
#         function geo_json_9a9b50f824fbe6c57b7038a0e1c47642_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9a9b50f824fbe6c57b7038a0e1c47642 = L.geoJson(null, {
#                 onEachFeature: geo_json_9a9b50f824fbe6c57b7038a0e1c47642_onEachFeature,
#
#         });
#
#         function geo_json_9a9b50f824fbe6c57b7038a0e1c47642_add (data) {
#             geo_json_9a9b50f824fbe6c57b7038a0e1c47642
#                 .addData(data)
#                 .addTo(map_29b9cca87a126e52052a08a2e75ffedc);
#         }
#             geo_json_9a9b50f824fbe6c57b7038a0e1c47642_add({&quot;bbox&quot;: [88.3364486, 22.463870099999998, 88.4126439, 22.6310988], &quot;features&quot;: [{&quot;bbox&quot;: [88.3555576143556, 22.5558619, 88.37555761435561, 22.575861900000003], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[88.37555761435561, 22.5658619], [88.37550946162233, 22.564881728596706], [88.37536546715964, 22.56391099677984], [88.37512701771293, 22.562959053227456], [88.37479640968073, 22.56203506567635], [88.3743768269991, 22.56114793263174], [88.37387231047863, 22.560306197669806], [88.37328771888923, 22.559517967158364], [88.37262868216747, 22.558790832188137], [88.37190154719724, 22.558131795466373], [88.37111331668581, 22.557547203876975], [88.37027158172387, 22.557042687356518], [88.36938444867926, 22.556623104674888], [88.36846046112815, 22.55629249664268], [88.36750851757577, 22.556054047195968], [88.36653778575891, 22.555910052733278], [88.36555761435561, 22.5558619], [88.36457744295231, 22.555910052733278], [88.36360671113545, 22.556054047195968], [88.36265476758307, 22.55629249664268], [88.36173078003196, 22.556623104674888], [88.36084364698735, 22.557042687356518], [88.36000191202541, 22.557547203876975], [88.35921368151398, 22.558131795466373], [88.35848654654374, 22.558790832188137], [88.35782750982199, 22.559517967158364], [88.35724291823259, 22.560306197669806], [88.35673840171212, 22.56114793263174], [88.35631881903049, 22.56203506567635], [88.35598821099829, 22.562959053227456], [88.35574976155158, 22.56391099677984], [88.35560576708889, 22.564881728596706], [88.3555576143556, 22.5658619], [88.35560576708889, 22.566842071403297], [88.35574976155158, 22.567812803220164], [88.35598821099829, 22.568764746772548], [88.35631881903049, 22.569688734323652], [88.35673840171212, 22.570575867368262], [88.35724291823259, 22.571417602330197], [88.35782750982199, 22.57220583284164], [88.35848654654374, 22.572932967811866], [88.35921368151398, 22.57359200453363], [88.36000191202541, 22.574176596123028], [88.36084364698735, 22.574681112643486], [88.36173078003196, 22.575100695325116], [88.36265476758307, 22.575431303357323], [88.36360671113545, 22.575669752804036], [88.36457744295231, 22.575813747266725], [88.36555761435561, 22.575861900000003], [88.36653778575891, 22.575813747266725], [88.36750851757577, 22.575669752804036], [88.36846046112815, 22.575431303357323], [88.36938444867926, 22.575100695325116], [88.37027158172387, 22.574681112643486], [88.37111331668581, 22.574176596123028], [88.37190154719724, 22.57359200453363], [88.37262868216747, 22.572932967811866], [88.37328771888923, 22.57220583284164], [88.37387231047863, 22.571417602330197], [88.3743768269991, 22.570575867368262], [88.37479640968073, 22.569688734323652], [88.37512701771293, 22.568764746772548], [88.37536546715964, 22.567812803220164], [88.37550946162233, 22.566842071403297], [88.37555761435561, 22.5658619]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [88.35520439999999, 22.595209599999997, 88.3752044, 22.6152096], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[88.3752044, 22.6052096], [88.37515624726672, 22.604229428596703], [88.37501225280403, 22.603258696779836], [88.37477380335731, 22.602306753227452], [88.37444319532511, 22.601382765676348], [88.37402361264348, 22.600495632631738], [88.37351909612302, 22.599653897669803], [88.37293450453362, 22.59886566715836

# %%
# Merging the buffers into a single polygon
merged_polygon = buffer_1km.unary_union

# %%
# Creating a new map for visualizing the merged polygon
merged_polygon_map = folium.Map(location=[y_avg, x_avg], tiles='CartoDB positron', zoom_start=11)

# %%
# Converting the merged polygon feature into a GeoPandas geoseries and then into a geojson object to add to the map

merged_polygon_geoj = gpd.GeoSeries(merged_polygon).to_json()
merged_polygon_geoj = folium.GeoJson(data=merged_polygon_geoj)
merged_polygon_geoj.add_to(merged_polygon_map)

merged_polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83e8f033252a39ccf6e8444379a41ebb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83e8f033252a39ccf6e8444379a41ebb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_83e8f033252a39ccf6e8444379a41ebb = L.map(
#                 &quot;map_83e8f033252a39ccf6e8444379a41ebb&quot;,
#                 {
#                     center: [22.561836789999997, 88.37639351186236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c05cbca79918022a1fd56fdc3b8e461e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83e8f033252a39ccf6e8444379a41ebb);
#
#
#
#         function geo_json_8f21297c5a3117f382c945730ce672b5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8f21297c5a3117f382c945730ce672b5 = L.geoJson(null, {
#                 onEachFeature: geo_json_8f21297c5a3117f382c945730ce672b5_onEachFeature,
#
#         });
#
#         function geo_json_8f21297c5a3117f382c945730ce672b5_add (data) {
#             geo_json_8f21297c5a3117f382c945730ce672b5
#                 .addData(data)
#                 .addTo(map_83e8f033252a39ccf6e8444379a41ebb);
#         }
#             geo_json_8f21297c5a3117f382c945730ce672b5_add({&quot;bbox&quot;: [88.3364486, 22.463870099999998, 88.4126439, 22.6310988], &quot;features&quot;: [{&quot;bbox&quot;: [88.3364486, 22.463870099999998, 88.4126439, 22.6310988], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[88.37153770335732, 22.470967253227453], [88.37120709532512, 22.47004326567635], [88.37078751264349, 22.46915613263174], [88.37028299612302, 22.468314397669804], [88.36969840453362, 22.46752616715836], [88.36903936781187, 22.466799032188135], [88.36831223284163, 22.46613999546637], [88.3675240023302, 22.465555403876973], [88.36668226736826, 22.465050887356515], [88.36579513432365, 22.464631304674885], [88.36487114677254, 22.464300696642677], [88.36391920322016, 22.464062247195965], [88.3629484714033, 22.463918252733276], [88.3619683, 22.463870099999998], [88.3609881285967, 22.463918252733276], [88.36001739677984, 22.464062247195965], [88.35906545322746, 22.464300696642677], [88.35814146567635, 22.464631304674885], [88.35725433263174, 22.465050887356515], [88.3564125976698, 22.465555403876973], [88.35562436715837, 22.46613999546637], [88.35489723218814, 22.466799032188135], [88.35423819546638, 22.46752616715836], [88.35365360387698, 22.468314397669804], [88.35314908735651, 22.46915613263174], [88.35272950467488, 22.47004326567635], [88.35239889664268, 22.470967253227453], [88.35216044719597, 22.471919196779837], [88.35201645273328, 22.472889928596704], [88.3519683, 22.4738701], [88.35201645273328, 22.474850271403294], [88.35216044719597, 22.47582100322016], [88.35239889664268, 22.476772946772545], [88.35272950467488, 22.47769693432365], [88.35314908735651, 22.47858406736826], [88.35365360387698, 22.479425802330194], [88.35423819546638, 22.480214032841637], [88.35489723218814, 22.480941167811864], [88.35562436715837, 22.481600204533628], [88.3564125976698, 22.482184796123025], [88.35725433263174, 22.482689312643483], [88.35814146567635, 22.483108895325113], [88.35906545322746, 22.48343950335732], [88.36001739677984, 22.483677952804033], [88.3609881285967, 22.483821947266723], [88.3619683, 22.4838701], [88.3629484714033, 22.483821947266723], [88.36391920322016, 22.483677952804033], [88.36487114677254, 22.48343950335732], [88.36579513432365, 22.483108895325113], [88.36668226736826, 22.482689312643483], [88.3675240023302, 22.482184796123025], [88.36831223284163, 22.481600204533628], [88.36903936781187, 22.480941167811864], [88.36969840453362, 22.480214032841637], [88.37028299612302, 22.479425802330194], [88.37078751264349, 22.47858406736826], [88.37120709532512, 22.47769693432365], [88.37153770335732, 22.476772946772545], [88.37177615280403, 22.47582100322016], [88.37192014726672, 22.474850271403294], [88.3719683, 22.4738701], [88.37192014726672, 22.472889928596704], [88.37177615280403, 22.471919196779837], [88.37153770335732, 22.470967253227453]]], [[[88.37291279532512, 22.50177866567635], [88.37249321264349, 22.50089153263174], [88.37198869612303, 22.500049797669806], [88.37140410453362, 22.499261567158364], [88.37074506781187, 22.498534432188137], [88.37001793284163, 22.497875395466373], [88.3692297023302, 22.497290803876975], [88.36838796736826, 22.496786287356517], [88.36750083432365, 22.496366704674887], [88.36657684677255, 22.49603609664268], [88.36562490322017, 22.495797647195968], [88.3646541714033, 22.495653652733278], [88.363674, 22.4956055], [88.3626938285967, 22.495653652733278], [88.36172309677984, 22.495797647195968], [88.36077115322746, 22.49603

# %%
# Loading the OSM geopackage file consisting of a points layer of the restaurants in Kolkata 

data_pkg_path = 'data'
filename = 'kolkata_restaurants.gpkg'
path = os.path.join(data_pkg_path, filename)

# Getting the restaurants vector layer as a GeoPandas geodataframe
restaurants_gdf = gpd.read_file(path, layer='kolkata_restaurants')

restaurants_gdf.head()
# Out:
#        full_id      osm_id osm_type     amenity         cuisine          name  \
# 0  n1783122342  1783122342     node  restaurant          indian         Dhaba
# 1  n1833168504  1833168504     node  restaurant          indian   Banana Leaf
# 2  n1833181230  1833181230     node  restaurant  chinese;indian     Bar-B-Que
# 3  n2234881738  2234881738     node  restaurant                  Oh! Calcutta
# 4  n2283710597  2283710597     node  restaurant                       Big Max
#
#   addr:postcode                 addr:street      alt_name  \
# 0
# 1      7000 026  73 & 75 Rash Behari Avenue  Komala Vilas
# 2                               Park Street
# 3        700020                  Elgin Road
# 4        700071               Russel Street
#
#                                     website  ... name:es alcohol  \
# 0                                            ...
# 1  http://www.bananaleaf.in/restaurant.html  ...
# 2                                            ...
# 3             https://www.speciality.co.in/  ...
# 4                                            ...
#
#   brand:wikipedia:pa brand:wikipedia:ur contact:phone contact:website  \
# 0
# 1
# 2
# 3
# 4
#
#   official_name diet:healthy opening_hours:covid19                   geometry
# 0                                                   POINT (88.36579 22.52822)
# 1                                                   POINT (88.34932 22.51700)
# 2                                                   POINT (88.35263 22.55308)
# 3                                                   POINT (88.35122 22.53806)
# 4                                                   POINT (88.35111 22.55377)
#
# [5 rows x 57 columns]

# %%
# Adding the restaurants to the merged plygon map

restaurants_gdf.apply(lambda restaurant:folium.Circle(radius=30, 
                                                      location=[restaurant['geometry'].y, restaurant['geometry'].x], 
                                                      popup=restaurant['name'], 
                                                      color='green', 
                                                      fill=True, 
                                                      fill_opacity=0.5
                                                     ).add_to(merged_polygon_map), axis=1)

merged_polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83e8f033252a39ccf6e8444379a41ebb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83e8f033252a39ccf6e8444379a41ebb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_83e8f033252a39ccf6e8444379a41ebb = L.map(
#                 &quot;map_83e8f033252a39ccf6e8444379a41ebb&quot;,
#                 {
#                     center: [22.561836789999997, 88.37639351186236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c05cbca79918022a1fd56fdc3b8e461e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83e8f033252a39ccf6e8444379a41ebb);
#
#
#
#         function geo_json_8f21297c5a3117f382c945730ce672b5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8f21297c5a3117f382c945730ce672b5 = L.geoJson(null, {
#                 onEachFeature: geo_json_8f21297c5a3117f382c945730ce672b5_onEachFeature,
#
#         });
#
#         function geo_json_8f21297c5a3117f382c945730ce672b5_add (data) {
#             geo_json_8f21297c5a3117f382c945730ce672b5
#                 .addData(data)
#                 .addTo(map_83e8f033252a39ccf6e8444379a41ebb);
#         }
#             geo_json_8f21297c5a3117f382c945730ce672b5_add({&quot;bbox&quot;: [88.3364486, 22.463870099999998, 88.4126439, 22.6310988], &quot;features&quot;: [{&quot;bbox&quot;: [88.3364486, 22.463870099999998, 88.4126439, 22.6310988], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[88.37153770335732, 22.470967253227453], [88.37120709532512, 22.47004326567635], [88.37078751264349, 22.46915613263174], [88.37028299612302, 22.468314397669804], [88.36969840453362, 22.46752616715836], [88.36903936781187, 22.466799032188135], [88.36831223284163, 22.46613999546637], [88.3675240023302, 22.465555403876973], [88.36668226736826, 22.465050887356515], [88.36579513432365, 22.464631304674885], [88.36487114677254, 22.464300696642677], [88.36391920322016, 22.464062247195965], [88.3629484714033, 22.463918252733276], [88.3619683, 22.463870099999998], [88.3609881285967, 22.463918252733276], [88.36001739677984, 22.464062247195965], [88.35906545322746, 22.464300696642677], [88.35814146567635, 22.464631304674885], [88.35725433263174, 22.465050887356515], [88.3564125976698, 22.465555403876973], [88.35562436715837, 22.46613999546637], [88.35489723218814, 22.466799032188135], [88.35423819546638, 22.46752616715836], [88.35365360387698, 22.468314397669804], [88.35314908735651, 22.46915613263174], [88.35272950467488, 22.47004326567635], [88.35239889664268, 22.470967253227453], [88.35216044719597, 22.471919196779837], [88.35201645273328, 22.472889928596704], [88.3519683, 22.4738701], [88.35201645273328, 22.474850271403294], [88.35216044719597, 22.47582100322016], [88.35239889664268, 22.476772946772545], [88.35272950467488, 22.47769693432365], [88.35314908735651, 22.47858406736826], [88.35365360387698, 22.479425802330194], [88.35423819546638, 22.480214032841637], [88.35489723218814, 22.480941167811864], [88.35562436715837, 22.481600204533628], [88.3564125976698, 22.482184796123025], [88.35725433263174, 22.482689312643483], [88.35814146567635, 22.483108895325113], [88.35906545322746, 22.48343950335732], [88.36001739677984, 22.483677952804033], [88.3609881285967, 22.483821947266723], [88.3619683, 22.4838701], [88.3629484714033, 22.483821947266723], [88.36391920322016, 22.483677952804033], [88.36487114677254, 22.48343950335732], [88.36579513432365, 22.483108895325113], [88.36668226736826, 22.482689312643483], [88.3675240023302, 22.482184796123025], [88.36831223284163, 22.481600204533628], [88.36903936781187, 22.480941167811864], [88.36969840453362, 22.480214032841637], [88.37028299612302, 22.479425802330194], [88.37078751264349, 22.47858406736826], [88.37120709532512, 22.47769693432365], [88.37153770335732, 22.476772946772545], [88.37177615280403, 22.47582100322016], [88.37192014726672, 22.474850271403294], [88.3719683, 22.4738701], [88.37192014726672, 22.472889928596704], [88.37177615280403, 22.471919196779837], [88.37153770335732, 22.470967253227453]]], [[[88.37291279532512, 22.50177866567635], [88.37249321264349, 22.50089153263174], [88.37198869612303, 22.500049797669806], [88.37140410453362, 22.499261567158364], [88.37074506781187, 22.498534432188137], [88.37001793284163, 22.497875395466373], [88.3692297023302, 22.497290803876975], [88.36838796736826, 22.496786287356517], [88.36750083432365, 22.496366704674887], [88.36657684677255, 22.49603609664268], [88.36562490322017, 22.495797647195968], [88.3646541714033, 22.495653652733278], [88.363674, 22.4956055], [88.3626938285967, 22.495653652733278], [88.36172309677984, 22.495797647195968], [88.36077115322746, 22.49603

# %%
# Generating a Pandas series of boolean values indicating which restaurants intersect the merged polygon
bool_series = restaurants_gdf['geometry'].intersects(merged_polygon)

# Using the boolean series to filter out the required restaurants from the restaurants geodataframe
restaurants_within_1km = restaurants_gdf[bool_series]

# Finally, we have the retaurants located within 1 km of the places to visit
restaurants_within_1km.head()
# Out:
#         full_id      osm_id osm_type     amenity cuisine         name  \
# 0   n1783122342  1783122342     node  restaurant  indian        Dhaba
# 1   n1833168504  1833168504     node  restaurant  indian  Banana Leaf
# 8   n2560440346  2560440346     node  restaurant  indian       Aminia
# 13  n3051834901  3051834901     node  restaurant  indian      Kasturi
# 15  n3410845680  3410845680     node  restaurant                Thali
#
#    addr:postcode                 addr:street      alt_name  \
# 0
# 1       7000 026  73 & 75 Rash Behari Avenue  Komala Vilas
# 8
# 13
# 15
#
#                                      website  ... name:es alcohol  \
# 0                                             ...
# 1   http://www.bananaleaf.in/restaurant.html  ...
# 8                                             ...
# 13                                            ...
# 15                                            ...
#
#    brand:wikipedia:pa brand:wikipedia:ur contact:phone contact:website  \
# 0
# 1
# 8
# 13
# 15
#
#    official_name diet:healthy opening_hours:covid19                   geometry
# 0                                                    POINT (88.36579 22.52822)
# 1                                                    POINT (88.34932 22.51700)
# 8                                                    POINT (88.36687 22.51681)
# 13                                                   POINT (88.36731 22.52723)
# 15                                                   POINT (88.38901 22.51576)
#
# [5 rows x 57 columns]

# %%
# Adding the filtered restaurants to the merged polygon map with yellow color...
# to compare with the rest of the restaurants in green color

restaurants_within_1km.apply(lambda restaurant:folium.Circle(radius=30, 
                                                             location=[restaurant['geometry'].y, restaurant['geometry'].x], 
                                                             popup=restaurant['name'], 
                                                             color='yellow', 
                                                             fill=True, 
                                                             fill_opacity=0.8).add_to(merged_polygon_map), axis=1)

merged_polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83e8f033252a39ccf6e8444379a41ebb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83e8f033252a39ccf6e8444379a41ebb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_83e8f033252a39ccf6e8444379a41ebb = L.map(
#                 &quot;map_83e8f033252a39ccf6e8444379a41ebb&quot;,
#                 {
#                     center: [22.561836789999997, 88.37639351186236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c05cbca79918022a1fd56fdc3b8e461e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83e8f033252a39ccf6e8444379a41ebb);
#
#
#
#         function geo_json_8f21297c5a3117f382c945730ce672b5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8f21297c5a3117f382c945730ce672b5 = L.geoJson(null, {
#                 onEachFeature: geo_json_8f21297c5a3117f382c945730ce672b5_onEachFeature,
#
#         });
#
#         function geo_json_8f21297c5a3117f382c945730ce672b5_add (data) {
#             geo_json_8f21297c5a3117f382c945730ce672b5
#                 .addData(data)
#                 .addTo(map_83e8f033252a39ccf6e8444379a41ebb);
#         }
#             geo_json_8f21297c5a3117f382c945730ce672b5_add({&quot;bbox&quot;: [88.3364486, 22.463870099999998, 88.4126439, 22.6310988], &quot;features&quot;: [{&quot;bbox&quot;: [88.3364486, 22.463870099999998, 88.4126439, 22.6310988], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[88.37153770335732, 22.470967253227453], [88.37120709532512, 22.47004326567635], [88.37078751264349, 22.46915613263174], [88.37028299612302, 22.468314397669804], [88.36969840453362, 22.46752616715836], [88.36903936781187, 22.466799032188135], [88.36831223284163, 22.46613999546637], [88.3675240023302, 22.465555403876973], [88.36668226736826, 22.465050887356515], [88.36579513432365, 22.464631304674885], [88.36487114677254, 22.464300696642677], [88.36391920322016, 22.464062247195965], [88.3629484714033, 22.463918252733276], [88.3619683, 22.463870099999998], [88.3609881285967, 22.463918252733276], [88.36001739677984, 22.464062247195965], [88.35906545322746, 22.464300696642677], [88.35814146567635, 22.464631304674885], [88.35725433263174, 22.465050887356515], [88.3564125976698, 22.465555403876973], [88.35562436715837, 22.46613999546637], [88.35489723218814, 22.466799032188135], [88.35423819546638, 22.46752616715836], [88.35365360387698, 22.468314397669804], [88.35314908735651, 22.46915613263174], [88.35272950467488, 22.47004326567635], [88.35239889664268, 22.470967253227453], [88.35216044719597, 22.471919196779837], [88.35201645273328, 22.472889928596704], [88.3519683, 22.4738701], [88.35201645273328, 22.474850271403294], [88.35216044719597, 22.47582100322016], [88.35239889664268, 22.476772946772545], [88.35272950467488, 22.47769693432365], [88.35314908735651, 22.47858406736826], [88.35365360387698, 22.479425802330194], [88.35423819546638, 22.480214032841637], [88.35489723218814, 22.480941167811864], [88.35562436715837, 22.481600204533628], [88.3564125976698, 22.482184796123025], [88.35725433263174, 22.482689312643483], [88.35814146567635, 22.483108895325113], [88.35906545322746, 22.48343950335732], [88.36001739677984, 22.483677952804033], [88.3609881285967, 22.483821947266723], [88.3619683, 22.4838701], [88.3629484714033, 22.483821947266723], [88.36391920322016, 22.483677952804033], [88.36487114677254, 22.48343950335732], [88.36579513432365, 22.483108895325113], [88.36668226736826, 22.482689312643483], [88.3675240023302, 22.482184796123025], [88.36831223284163, 22.481600204533628], [88.36903936781187, 22.480941167811864], [88.36969840453362, 22.480214032841637], [88.37028299612302, 22.479425802330194], [88.37078751264349, 22.47858406736826], [88.37120709532512, 22.47769693432365], [88.37153770335732, 22.476772946772545], [88.37177615280403, 22.47582100322016], [88.37192014726672, 22.474850271403294], [88.3719683, 22.4738701], [88.37192014726672, 22.472889928596704], [88.37177615280403, 22.471919196779837], [88.37153770335732, 22.470967253227453]]], [[[88.37291279532512, 22.50177866567635], [88.37249321264349, 22.50089153263174], [88.37198869612303, 22.500049797669806], [88.37140410453362, 22.499261567158364], [88.37074506781187, 22.498534432188137], [88.37001793284163, 22.497875395466373], [88.3692297023302, 22.497290803876975], [88.36838796736826, 22.496786287356517], [88.36750083432365, 22.496366704674887], [88.36657684677255, 22.49603609664268], [88.36562490322017, 22.495797647195968], [88.3646541714033, 22.495653652733278], [88.363674, 22.4956055], [88.3626938285967, 22.495653652733278], [88.36172309677984, 22.495797647195968], [88.36077115322746, 22.49603

# %% [markdown]
# ***
# ### Putting it all together
#
# Finally! We are done with our spatial analysis. Now, it's time to visulaize the Durga Puja places to visit, the optimum route to travel from my home to all these locations, and the restaurants I can reach within 1 km of these places - all together on our Kolkata map.

# %%
# Adding the filtered restaurants to the Kolkata map

restaurants_within_1km.apply(lambda restaurant:folium.Circle(radius=30, 
                                                             location=[restaurant['geometry'].y, restaurant['geometry'].x], 
                                                             popup=restaurant['name'], 
                                                             color='green', 
                                                             fill=True, 
                                                             fill_color='yellow', 
                                                             fill_opacity=0.5).add_to(kolkata_map), axis=1)

# Our final map is ready!
kolkata_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a91bff6d9e1e15e07478ce0028690e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a91bff6d9e1e15e07478ce0028690e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8a91bff6d9e1e15e07478ce0028690e3 = L.map(
#                 &quot;map_8a91bff6d9e1e15e07478ce0028690e3&quot;,
#                 {
#                     center: [22.561836789999997, 88.37639351186236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7297f3e5daf85bfb6281e0ec687743f4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var marker_81051bb35ed3c78a78a5ebcec0e301eb = L.marker(
#                 [22.707052, 88.463047],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_0479e744cf31955635e610d9c2939323 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81051bb35ed3c78a78a5ebcec0e301eb.setIcon(icon_0479e744cf31955635e610d9c2939323);
#
#
#         var popup_8c0691e27ac5a62c53426be005d0bf26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3009b02877d8f2beed01442eaa03655 = $(`&lt;div id=&quot;html_f3009b02877d8f2beed01442eaa03655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Home&lt;/div&gt;`)[0];
#             popup_8c0691e27ac5a62c53426be005d0bf26.setContent(html_f3009b02877d8f2beed01442eaa03655);
#
#
#         marker_81051bb35ed3c78a78a5ebcec0e301eb.bindPopup(popup_8c0691e27ac5a62c53426be005d0bf26)
#         ;
#
#
#
#
#             var marker_65030b681c7bad782ef367c1684b2845 = L.marker(
#                 [22.5658619, 88.36555761435561],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_3612ae3275b2f194b62b87e187e71b68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_65030b681c7bad782ef367c1684b2845.setIcon(icon_3612ae3275b2f194b62b87e187e71b68);
#
#
#         var popup_1d365cb7b18493be7bccd19538f1b1d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_16bde4e0197f948e4410427b3085832a = $(`&lt;div id=&quot;html_16bde4e0197f948e4410427b3085832a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santosh Mitra Square&lt;/div&gt;`)[0];
#             popup_1d365cb7b18493be7bccd19538f1b1d4.setContent(html_16bde4e0197f948e4410427b3085832a);
#
#
#         marker_65030b681c7bad782ef367c1684b2845.bindPopup(popup_1d365cb7b18493be7bccd19538f1b1d4)
#         ;
#
#
#
#
#             var marker_03285b6ad88884a73f4db47d0f6c1a81 = L.marker(
#                 [22.6052096, 88.3652044],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_6cc366d529c604c324a2c12d09f02b24 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_03285b6ad88884a73f4db47d0f6c1a81.setIcon(icon_6cc366d529c604c324a2c12d09f02b24);
#
#
#         var popup_de530c42481a2019b057c3185ddabc1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f5fb96c98c2601774f55a4d614ec56ae = $(`&lt;div id=&quot;html_f5fb96c98c2601774f55a4d614ec56ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bagbazar&lt;/div&gt;`)[0];
#             popup_de530c42481a2019b057c3185ddabc1f.setContent(html_f5fb96c98c2601774f55a4d614ec56ae);
#
#
#         marker_03285b6ad88884a73f4db47d0f6c1a81.bindPopup(popup_de530c42481a2019b057c3185ddabc1f)
#         ;
#
#
#
#
#             var marker_00ad71acc71b56ec6acdb90957b1c46b = L.marker(
#                 [22.57465335, 88.36390478535333],
#                 {}
#             ).addTo(map_8a91bff6d9e1e15e07478ce0028690e3);
#
#
#             var icon_d85e4f571c1ac80ad4a3ea1ec5994bb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;
