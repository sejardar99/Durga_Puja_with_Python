# %% [markdown]
# ## <center>CLASS PROJECT FOR THE SPATIAL THOUGHTS<br> 'PYTHON FOUNDATION FOR SPATIAL ANALYSIS' COURSE</center>

# %% [markdown]
# <div style="text-align: justify">I recently moved to the city of Kolkata in West Bengal, India. When I started thinking of some idea for this project, the first thing that came to my mind was that I could use Python to get the locations of some of the most famous Durga Puja pandals of Kolkata, find an optimum route to visit all these places starting right from my home, and finally look for all restaurants located within 1 km of all these places I shall visit. And my Durga Puja plan for this year just got sorted! Thanks to Python's spatial analysis!</div>
#
# ***

# %% [markdown]
# First we shall import all the Python libraries we need for this project.

# %%
import pandas as pd
import geopandas as gpd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import folium
import requests
import os

# %% [markdown]
# ### Getting the coordinates and geometry of the places
#
# We shall geocode the places to visit, add my home location to the list and then get the geometry of all these places.

# %%
# Creating a list of Kolkata's Durga Puja locations to visit

places = ['Santosh Mitra Square', 
          'Bagbazar', 
          'College Square', 
          'Hindustan Park', 
          'Deshapriya Park', 
          'Ahiritola', 
          'Lake Town', 
          'Manicktala', 
          'Ekdalia', 
          'Mudiali', 
          'Bosepukur', 
          'Naktala', 
          'Jodhpur Park']

# %%
# Creating a Pandas dataframe of the places
places_df = pd.DataFrame(places, columns = ['places'])
places_df
# Out:
#                   places
# 0   Santosh Mitra Square
# 1               Bagbazar
# 2         College Square
# 3         Hindustan Park
# 4        Deshapriya Park
# 5              Ahiritola
# 6              Lake Town
# 7             Manicktala
# 8                Ekdalia
# 9                Mudiali
# 10             Bosepukur
# 11               Naktala
# 12          Jodhpur Park

# %%
# Using the Nominatim Geocoding Service from geopy library to geocode the places

# user_id = '<replace with your unique id>'

locator = Nominatim(user_agent=user_id)

# Function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# Applying the geocode function on our places dataframe
places_df['location'] = (places_df['places'] + ', Kolkata, West Bengal, India').apply(geocode)

places_df
# Out:
#                   places                                           location
# 0   Santosh Mitra Square  (Santosh Mitra Square, Chandi Chowk East, Kolk...
# 1               Bagbazar  (Bagbazar, Rabindra Sarani, Tiretta Bazaar, Jo...
# 2         College Square  (College Square Park, Tiretta Bazaar, Bow Baza...
# 3         Hindustan Park  (Hindustan Park, Dhakuria, Kolkata, West Benga...
# 4        Deshapriya Park  (Deshapriya Park, Manoharpukur, Kolkata, West ...
# 5              Ahiritola  (Ahiritola Street, Shobha Bazar, Kolkata, West...
# 6              Lake Town  (Lake town, Radha Gobinda Kar Road, Lake Town,...
# 7             Manicktala  (Frank Ross Pharmacy, P-14, CIT Rd, Manicktala...
# 8                Ekdalia  (Ekdalia, Rash Behari Avenue Connector, Kushit...
# 9                Mudiali  (Mudiali Club, SR Das Road, Kalighat, Kolkata,...
# 10             Bosepukur  (Bosepukur Shitalamandir, Rash Behari Avenue C...
# 11               Naktala  (Naktala, Netaji Subhash Chandra Bose Road, Sh...
# 12          Jodhpur Park  (Jodhpur Park, Kolkata, West Bengal, 700068, I...

# %%
# Extracting coordinates of the places and creating columns for latitude and longitude values
places_df['latitude'] = places_df['location'].apply(lambda loc: loc.latitude)
places_df['longitude'] = places_df['location'].apply(lambda loc: loc.longitude)

# Removing the 'location' column from the places dataframe
places_df = places_df.drop('location', axis=1)

places_df
# Out:
#                   places   latitude  longitude
# 0   Santosh Mitra Square  22.565862  88.365558
# 1               Bagbazar  22.605210  88.365204
# 2         College Square  22.574653  88.363905
# 3         Hindustan Park  22.518114  88.361752
# 4        Deshapriya Park  22.518435  88.353515
# 5              Ahiritola  22.595334  88.355472
# 6              Lake Town  22.609751  88.402644
# 7             Manicktala  22.581753  88.390794
# 8                Ekdalia  22.521226  88.369451
# 9                Mudiali  22.510081  88.346449
# 10             Bosepukur  22.519288  88.385335
# 11               Naktala  22.473870  88.361968
# 12          Jodhpur Park  22.505606  88.363674

# %%
# Coordinates of my home
home_coordinates = (22.707052, 88.463047)

# %%
# Creating a Pandas dataframe of just my home location

my_home = pd.DataFrame({'places':'My Home', 
                        'latitude':home_coordinates[0], 
                        'longitude':home_coordinates[1]}, 
                       columns=['places', 'latitude', 'longitude'], 
                       index=[0])

my_home
# Out:
#     places   latitude  longitude
# 0  My Home  22.707052  88.463047

# %%
# Adding my home location to the places dataframe
places_df_concat = pd.concat([my_home, places_df]).reset_index(drop=True)
places_df_concat
# Out:
#                   places   latitude  longitude
# 0                My Home  22.707052  88.463047
# 1   Santosh Mitra Square  22.565862  88.365558
# 2               Bagbazar  22.605210  88.365204
# 3         College Square  22.574653  88.363905
# 4         Hindustan Park  22.518114  88.361752
# 5        Deshapriya Park  22.518435  88.353515
# 6              Ahiritola  22.595334  88.355472
# 7              Lake Town  22.609751  88.402644
# 8             Manicktala  22.581753  88.390794
# 9                Ekdalia  22.521226  88.369451
# 10               Mudiali  22.510081  88.346449
# 11             Bosepukur  22.519288  88.385335
# 12               Naktala  22.473870  88.361968
# 13          Jodhpur Park  22.505606  88.363674

# %%
# Creating a GeoPandas geodataframe of the places

# Getting the geometry of the locations 
geometry = gpd.points_from_xy(places_df_concat.longitude, places_df_concat.latitude)

# Converting the places dataframe into a geodataframe 
places_gdf = gpd.GeoDataFrame(places_df_concat, crs='EPSG:4326', geometry=geometry)

places_gdf
# Out:
#                   places   latitude  longitude                   geometry
# 0                My Home  22.707052  88.463047  POINT (88.46305 22.70705)
# 1   Santosh Mitra Square  22.565862  88.365558  POINT (88.36556 22.56586)
# 2               Bagbazar  22.605210  88.365204  POINT (88.36520 22.60521)
# 3         College Square  22.574653  88.363905  POINT (88.36390 22.57465)
# 4         Hindustan Park  22.518114  88.361752  POINT (88.36175 22.51811)
# 5        Deshapriya Park  22.518435  88.353515  POINT (88.35352 22.51844)
# 6              Ahiritola  22.595334  88.355472  POINT (88.35547 22.59533)
# 7              Lake Town  22.609751  88.402644  POINT (88.40264 22.60975)
# 8             Manicktala  22.581753  88.390794  POINT (88.39079 22.58175)
# 9                Ekdalia  22.521226  88.369451  POINT (88.36945 22.52123)
# 10               Mudiali  22.510081  88.346449  POINT (88.34645 22.51008)
# 11             Bosepukur  22.519288  88.385335  POINT (88.38533 22.51929)
# 12               Naktala  22.473870  88.361968  POINT (88.36197 22.47387)
# 13          Jodhpur Park  22.505606  88.363674  POINT (88.36367 22.50561)

# %% [markdown]
# ### Mapping the places
#
# Now, we shall visualize our places on a map using the Folium library.

# %%
# Getting the central coordinates to position the basemap
x_avg = places_gdf['longitude'].sum()/14
y_avg = places_gdf['latitude'].sum()/14

y_avg, x_avg
# Out:
# (22.557588239285714, 88.37491196052135)

# %%
# Creating the basemap 
kolkata_map = folium.Map(location=[y_avg, x_avg], tiles='CartoDB positron', zoom_start=11)

# %%
# Getting the places geodataframe's first row that contains my home location 
home = places_gdf.iloc[0]

# Adding my home location to the map with a red home-icon marker
folium.Marker(location=[home.latitude, home.longitude], 
              popup=home.places, 
              icon=folium.Icon(color='red', icon='home')).add_to(kolkata_map)

# Adding the rest of the places to the map, each with a blue map-marker
places_gdf.iloc[1:].apply(lambda place:folium.Marker(location=[place['latitude'], place['longitude']], 
                                                     popup=place['places'], 
                                                     icon=folium.Icon(color='blue', icon='map-marker')
                                                    ).add_to(kolkata_map), axis=1)

kolkata_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad66ea6cea0b3605b880d9ca42798bb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad66ea6cea0b3605b880d9ca42798bb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ad66ea6cea0b3605b880d9ca42798bb6 = L.map(
#                 &quot;map_ad66ea6cea0b3605b880d9ca42798bb6&quot;,
#                 {
#                     center: [22.557588239285714, 88.37491196052135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5888eef4f6b93f0534953e3ad111b05 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var marker_95dc3319fec329abc913cb053c8fb239 = L.marker(
#                 [22.707052, 88.463047],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_d892f8ffaeec0f67a9793104fae64b89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_95dc3319fec329abc913cb053c8fb239.setIcon(icon_d892f8ffaeec0f67a9793104fae64b89);
#
#
#         var popup_04396997bcd58604b715f933cd6269a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4f7344f6c5ca43b49e2bee0cba10dc97 = $(`&lt;div id=&quot;html_4f7344f6c5ca43b49e2bee0cba10dc97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Home&lt;/div&gt;`)[0];
#             popup_04396997bcd58604b715f933cd6269a2.setContent(html_4f7344f6c5ca43b49e2bee0cba10dc97);
#
#
#         marker_95dc3319fec329abc913cb053c8fb239.bindPopup(popup_04396997bcd58604b715f933cd6269a2)
#         ;
#
#
#
#
#             var marker_b6c15a092053ee67daf9f5d135b728ab = L.marker(
#                 [22.5658619, 88.36555761435561],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_b9e7c96829691c7e6a13c9ea30ef2d12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6c15a092053ee67daf9f5d135b728ab.setIcon(icon_b9e7c96829691c7e6a13c9ea30ef2d12);
#
#
#         var popup_e8d7b2bbcfcb172de7aadc5d1ce3e412 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1f881c85601eda3d54328df651262df6 = $(`&lt;div id=&quot;html_1f881c85601eda3d54328df651262df6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santosh Mitra Square&lt;/div&gt;`)[0];
#             popup_e8d7b2bbcfcb172de7aadc5d1ce3e412.setContent(html_1f881c85601eda3d54328df651262df6);
#
#
#         marker_b6c15a092053ee67daf9f5d135b728ab.bindPopup(popup_e8d7b2bbcfcb172de7aadc5d1ce3e412)
#         ;
#
#
#
#
#             var marker_c78fde0035f3f6b6ffda1c71f0e77a1a = L.marker(
#                 [22.6052096, 88.3652044],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_e4bd21c951744caf54bc43f91fa21c84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c78fde0035f3f6b6ffda1c71f0e77a1a.setIcon(icon_e4bd21c951744caf54bc43f91fa21c84);
#
#
#         var popup_85e8820250edb2e92980473e0459d93a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6f30da73fb21e4c573e5120bb158534c = $(`&lt;div id=&quot;html_6f30da73fb21e4c573e5120bb158534c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bagbazar&lt;/div&gt;`)[0];
#             popup_85e8820250edb2e92980473e0459d93a.setContent(html_6f30da73fb21e4c573e5120bb158534c);
#
#
#         marker_c78fde0035f3f6b6ffda1c71f0e77a1a.bindPopup(popup_85e8820250edb2e92980473e0459d93a)
#         ;
#
#
#
#
#             var marker_f712093ddc6f83f937e3a08eb432fb16 = L.marker(
#                 [22.57465335, 88.36390478535333],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_458e2cba1f7c844e8ee300e89293031f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;

# %% [markdown]
# ### Finding and mapping the optimum route to visit the places
#
# Next, we shall use the Optimization service of the OpenRouteService API to get the optimum route to travel from my home to the Durga Puja locations in the city, and then visualize the route on our Kolkata map.

# %%
# It is clearly visible on the map that geographically 'Naktala' is the farthest location from my house. 
# Hence, we shall consider it the endpoint of our optimum route.

# Getting the row of 'Naktala' from the places geodataframe
endpoint = places_gdf.iloc[12]
endpoint
# Out:
# places                             Naktala
# latitude                          22.47387
# longitude                        88.361968
# geometry     POINT (88.3619683 22.4738701)
# Name: 12, dtype: object

# %%
# And my home location will be the starting point of our optimum route.

home
# Out:
# places                           My Home
# latitude                       22.707052
# longitude                      88.463047
# geometry     POINT (88.463047 22.707052)
# Name: 0, dtype: object

# %%
# Creating the vehicles and jobs parameters for the Optimization API call


# Vehicle to travel
vehicle = [{"id":1,
            "profile":"driving-car",
            "start":[home.longitude, home.latitude],
            "end":[endpoint.longitude, endpoint.latitude]}]


# Places to visit
jobs = []
# For loop to append the places from index 1 to 12, excluding the start('My Home') and end('Naktala') points
for i in range(1,12):
    place_dict = {}
    place = places_gdf.iloc[i]
    place_dict['id'] = i
    place_dict['location'] = [place.longitude, place.latitude]
    jobs.append(place_dict)
    
# Appending the remaining location which is at the last index position of the places geodataframe
last_row = places_gdf.iloc[-1]
jobs.append({'id':12, 'location':[last_row.longitude, last_row.latitude]})

# %%
vehicle
# Out:
# [{'id': 1,
#   'profile': 'driving-car',
#   'start': [88.463047, 22.707052],
#   'end': [88.3619683, 22.4738701]}]

# %%
jobs
# Out:
# [{'id': 1, 'location': [88.36555761435561, 22.5658619]},
#  {'id': 2, 'location': [88.3652044, 22.6052096]},
#  {'id': 3, 'location': [88.36390478535333, 22.57465335]},
#  {'id': 4, 'location': [88.3617522, 22.5181145]},
#  {'id': 5, 'location': [88.35351524759007, 22.5184354]},
#  {'id': 6, 'location': [88.3554724, 22.595334]},
#  {'id': 7, 'location': [88.4026439, 22.6097509]},
#  {'id': 8, 'location': [88.3907936, 22.5817532]},
#  {'id': 9, 'location': [88.3694508, 22.521226]},
#  {'id': 10, 'location': [88.3464486, 22.5100811]},
#  {'id': 11, 'location': [88.3853346, 22.5192878]},
#  {'id': 12, 'location': [88.363674, 22.5056055]}]

# %%
# Using the Optimization service of the OpenRouteService API 

# ORS_API_KEY = '<replace with your unique ORS API key>'

body = {'jobs':jobs, 'vehicles':vehicle}

headers = {'Accept':'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8', 
           'Authorization':ORS_API_KEY, 
           'Content-Type':'application/json; charset=utf-8'}

# Using the requests library to make the API call
response = requests.post('https://api.openrouteservice.org/optimization', json=body, headers=headers)


# Getting the response in json format if the API request is successful 
if response.status_code == 200:
    print('Request successful.')
    optimization_data = response.json()
else:
    print('Request failed.')
# Out:
# Request successful.

# %%
optimization_data
# Out:
# {'code': 0,
#  'summary': {'cost': 4919,
#   'unassigned': 0,
#   'service': 0,
#   'duration': 4919,
#   'waiting_time': 0,
#   'computing_times': {'loading': 111, 'solving': 1}},
#  'unassigned': [],
#  'routes': [{'vehicle': 1,
#    'cost': 4919,
#    'service': 0,
#    'duration': 4919,
#    'waiting_time': 0,
#    'steps': [{'type': 'start',
#      'location': [88.463047, 22.707052],
#      'arrival': 0,
#      'duration': 0},
#     {'type': 'job',
#      'location': [88.4026439, 22.6097509],
#      'id': 7,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 7,
#      'arrival': 1245,
#      'duration': 1245},
#     {'type': 'job',
#      'location': [88.3907936, 22.5817532],
#      'id': 8,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 8,
#      'arrival': 1650,
#      'duration': 1650},
#     {'type': 'job',
#      'location': [88.3652044, 22.6052096],
#      'id': 2,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 2,
#      'arrival': 2032,
#      'duration': 2032},
#     {'type': 'job',
#      'location': [88.3554724, 22.595334],
#      'id': 6,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 6,
#      'arrival': 2197,
#      'duration': 2197},
#     {'type': 'job',
#      'location': [88.36390478535333, 22.57465335],
#      'id': 3,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 3,
#      'arrival': 2427,
#      'duration': 2427},
#     {'type': 'job',
#      'location': [88.36555761435561, 22.5658619],
#      'id': 1,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 1,
#      'arrival': 2546,
#      'duration': 2546},
#     {'type': 'job',
#      'location': [88.3694508, 22.521226],
#      'id': 9,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 9,
#      'arrival': 3171,
#      'duration': 3171},
#     {'type': 'job',
#      'location': [88.3853346, 22.5192878],
#      'id': 11,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 11,
#      'arrival': 3346,
#      'duration': 3346},
#     {'type': 'job',
#      'location': [88.3617522, 22.5181145],
#      'id': 4,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 4,
#      'arrival': 3726,
#      'duration': 3726},
#     {'type': 'job',
#      'location': [88.35351524759007, 22.5184354],
#      'id': 5,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 5,
#      'arrival': 3858,
#      'duration': 3858},
#     {'type': 'job',
#      'location': [88.3464486, 22.5100811],
#      'id': 10,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 10,
#      'arrival': 4062,
#      'duration': 4062},
#     {'type': 'job',
#      'location': [88.363674, 22.5056055],
#      'id': 12,
#      'service': 0,
#      'waiting_time': 0,
#      'job': 12,
#      'arrival': 4423,
#      'duration': 4423},
#     {'type': 'end',
#      'location': [88.3619683, 22.4738701],
#      'arrival': 4919,
#      'duration': 4919}]}]}

# %%
# Creating a list of coordinates of the locations on the optimum route

optimum_route_points = []

steps = optimization_data['routes'][0]['steps']

for step in steps:
    optimum_route_points.append((step['location'][1], step['location'][0]))
    
optimum_route_points
# Out:
# [(22.707052, 88.463047),
#  (22.6097509, 88.4026439),
#  (22.5817532, 88.3907936),
#  (22.6052096, 88.3652044),
#  (22.595334, 88.3554724),
#  (22.57465335, 88.36390478535333),
#  (22.5658619, 88.36555761435561),
#  (22.521226, 88.3694508),
#  (22.5192878, 88.3853346),
#  (22.5181145, 88.3617522),
#  (22.5184354, 88.35351524759007),
#  (22.5100811, 88.3464486),
#  (22.5056055, 88.363674),
#  (22.4738701, 88.3619683)]

# %%
# Adding the optimum route as a polyline geometry feature to the Kolkata map
folium.PolyLine(optimum_route_points, color='red', weight=1.5, opacity=2).add_to(kolkata_map)

kolkata_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad66ea6cea0b3605b880d9ca42798bb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad66ea6cea0b3605b880d9ca42798bb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ad66ea6cea0b3605b880d9ca42798bb6 = L.map(
#                 &quot;map_ad66ea6cea0b3605b880d9ca42798bb6&quot;,
#                 {
#                     center: [22.557588239285714, 88.37491196052135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5888eef4f6b93f0534953e3ad111b05 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var marker_95dc3319fec329abc913cb053c8fb239 = L.marker(
#                 [22.707052, 88.463047],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_d892f8ffaeec0f67a9793104fae64b89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_95dc3319fec329abc913cb053c8fb239.setIcon(icon_d892f8ffaeec0f67a9793104fae64b89);
#
#
#         var popup_04396997bcd58604b715f933cd6269a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4f7344f6c5ca43b49e2bee0cba10dc97 = $(`&lt;div id=&quot;html_4f7344f6c5ca43b49e2bee0cba10dc97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Home&lt;/div&gt;`)[0];
#             popup_04396997bcd58604b715f933cd6269a2.setContent(html_4f7344f6c5ca43b49e2bee0cba10dc97);
#
#
#         marker_95dc3319fec329abc913cb053c8fb239.bindPopup(popup_04396997bcd58604b715f933cd6269a2)
#         ;
#
#
#
#
#             var marker_b6c15a092053ee67daf9f5d135b728ab = L.marker(
#                 [22.5658619, 88.36555761435561],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_b9e7c96829691c7e6a13c9ea30ef2d12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6c15a092053ee67daf9f5d135b728ab.setIcon(icon_b9e7c96829691c7e6a13c9ea30ef2d12);
#
#
#         var popup_e8d7b2bbcfcb172de7aadc5d1ce3e412 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1f881c85601eda3d54328df651262df6 = $(`&lt;div id=&quot;html_1f881c85601eda3d54328df651262df6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santosh Mitra Square&lt;/div&gt;`)[0];
#             popup_e8d7b2bbcfcb172de7aadc5d1ce3e412.setContent(html_1f881c85601eda3d54328df651262df6);
#
#
#         marker_b6c15a092053ee67daf9f5d135b728ab.bindPopup(popup_e8d7b2bbcfcb172de7aadc5d1ce3e412)
#         ;
#
#
#
#
#             var marker_c78fde0035f3f6b6ffda1c71f0e77a1a = L.marker(
#                 [22.6052096, 88.3652044],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_e4bd21c951744caf54bc43f91fa21c84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c78fde0035f3f6b6ffda1c71f0e77a1a.setIcon(icon_e4bd21c951744caf54bc43f91fa21c84);
#
#
#         var popup_85e8820250edb2e92980473e0459d93a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6f30da73fb21e4c573e5120bb158534c = $(`&lt;div id=&quot;html_6f30da73fb21e4c573e5120bb158534c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bagbazar&lt;/div&gt;`)[0];
#             popup_85e8820250edb2e92980473e0459d93a.setContent(html_6f30da73fb21e4c573e5120bb158534c);
#
#
#         marker_c78fde0035f3f6b6ffda1c71f0e77a1a.bindPopup(popup_85e8820250edb2e92980473e0459d93a)
#         ;
#
#
#
#
#             var marker_f712093ddc6f83f937e3a08eb432fb16 = L.marker(
#                 [22.57465335, 88.36390478535333],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_458e2cba1f7c844e8ee300e89293031f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;

# %% [markdown]
# ### Finding all restaurants located within 1 km of each place to visit
#
# Now, we shall create buffers of 1 km around each place to visit, merge all the buffers into a single polygon feature to get rid of intersecting buffer polygons, load an OpenStreetMap geopackage file containing a points layer of restaurants in Kolkata, and extract only those restaurants which fall within the merged buffer polygon.

# %%
# Reprojecting the places geodataframe to a projeccted CRS - WGS 84 UTM 45N, which covers West Bengal

places_gdf_reprojected = places_gdf.to_crs('EPSG:32645')
places_gdf_reprojected = places_gdf_reprojected.drop(['latitude', 'longitude'], axis=1)
places_gdf_reprojected
# Out:
#                   places                        geometry
# 0                My Home  POINT (650268.434 2511831.810)
# 1   Santosh Mitra Square  POINT (640397.409 2496104.231)
# 2               Bagbazar  POINT (640321.215 2500460.329)
# 3         College Square  POINT (640218.558 2497076.031)
# 4         Hindustan Park  POINT (640054.285 2490814.274)
# 5        Deshapriya Park  POINT (639206.692 2490842.113)
# 6              Ahiritola  POINT (639330.730 2499357.809)
# 7              Lake Town  POINT (644165.203 2500998.872)
# 8             Manicktala  POINT (642975.963 2497887.624)
# 9                Ekdalia  POINT (640843.028 2491165.996)
# 10               Mudiali  POINT (638488.128 2489910.608)
# 11             Bosepukur  POINT (642478.831 2490966.453)
# 12               Naktala  POINT (640121.075 2485915.958)
# 13          Jodhpur Park  POINT (640264.588 2489431.138)

# %%
# Creating a GeoPandas geoseries of buffers of 1 km around the places to visit
buffer_1km = places_gdf_reprojected['geometry'][1:].buffer(1000)

# %%
# Creating a new map to visualize the buffers
buffer_map = folium.Map(location=[y_avg, x_avg], tiles='CartoDB positron', zoom_start=11)

# %%
# Reprojecting the buffers geoseries to a geographic CRS for visualization on map...
# and then converting the buffers geoseries into a geojson object to add to the map

buffer_geojson = buffer_1km.to_crs('EPSG:4326').to_json()
buffer_geojson = folium.GeoJson(data=buffer_geojson)
buffer_geojson.add_to(buffer_map)


buffer_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb9d1b1e7e14ebef8a5c14e18fceb2c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb9d1b1e7e14ebef8a5c14e18fceb2c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_eb9d1b1e7e14ebef8a5c14e18fceb2c9 = L.map(
#                 &quot;map_eb9d1b1e7e14ebef8a5c14e18fceb2c9&quot;,
#                 {
#                     center: [22.557588239285714, 88.37491196052135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5529e823cf153e8c7169c512c6d16f68 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eb9d1b1e7e14ebef8a5c14e18fceb2c9);
#
#
#
#         function geo_json_957d82bae22aeea4725102dcc8400128_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_957d82bae22aeea4725102dcc8400128 = L.geoJson(null, {
#                 onEachFeature: geo_json_957d82bae22aeea4725102dcc8400128_onEachFeature,
#
#         });
#
#         function geo_json_957d82bae22aeea4725102dcc8400128_add (data) {
#             geo_json_957d82bae22aeea4725102dcc8400128
#                 .addData(data)
#                 .addTo(map_eb9d1b1e7e14ebef8a5c14e18fceb2c9);
#         }
#             geo_json_957d82bae22aeea4725102dcc8400128_add({&quot;bbox&quot;: [88.33672815470287, 22.464838617892287, 88.41237105683211, 22.618782063760488], &quot;features&quot;: [{&quot;bbox&quot;: [88.35583334028193, 22.556830534509174, 88.37528184310054, 22.5748932550169], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[88.37528184310054, 22.565778989508487], [88.37522623775969, 22.56489416558335], [88.37507752071228, 22.56401866400285], [88.37483712585686, 22.56316091598965], [88.3745073698419, 22.56232918165009], [88.37409142969705, 22.561531470443246], [88.3735933121867, 22.560775464068342], [88.37301781518299, 22.56006844251261], [88.37237048143176, 22.559417213970463], [88.37165754515779, 22.558828049308], [88.37088587202395, 22.558306621702638], [88.37006289302289, 22.557857952038045], [88.36919653293717, 22.557486360579052], [88.36829513405591, 22.55719542539082], [88.36736737588143, 22.556987947901746], [88.36642219159695, 22.55686592594092], [88.36546868209795, 22.556830534509174], [88.36451602841268, 22.556882114468433], [88.36357340335246, 22.55702016925813], [88.36264988324031, 22.557243369670356], [88.36175436056516, 22.557549566638002], [88.36089545840048, 22.55793581191319], [88.36008144740929, 22.55839838643766], [88.35932016623289, 22.558932836132673], [88.3586189460285, 22.55953401476474], [88.35798453988144, 22.560196133475653], [88.3574230577712, 22.560912816500796], [88.35693990771738, 22.56167716254055], [88.35653974367303, 22.562481811194733], [88.35622642066791, 22.563319013821577], [88.35600295763517, 22.564180708139624], [88.35587150828131, 22.565058595855117], [88.35583334028193, 22.565944222567765], [88.35588882300632, 22.56682905918592], [88.35603742389132, 22.567704584067194], [88.35627771350245, 22.568562365093488], [88.35660737923565, 22.56939414088978], [88.35702324753082, 22.570191900403838], [88.35752131438467, 22.57094796008001], [88.35809678387179, 22.57165503788274], [88.35874411430376, 22.572306323456065], [88.35945707158339, 22.572895543742224], [88.36022878924055, 22.573417023426188], [88.36105183457158, 22.573865739622967], [88.36191828024492, 22.5742373702795], [88.36281978068233, 22.574528335824308], [88.36374765247878, 22.57473583366238], [88.3646929580846, 22.574857865182643], [88.36564659194202, 22.5748932550169], [88.36659936824375, 22.57484166236462], [88.36754210946638, 22.574703584274147], [88.36846573482286, 22.57448035084883], [88.36936134777976, 22.574174112424455], [88.37022032179411, 22.57378781884206], [88.37103438344178, 22.573325191016302], [88.37179569213478, 22.5727906850743], [88.37249691565842, 22.572189449411045], [88.37313130079981, 22.571527275076445], [88.37369273838674, 22.570810539972697], [88.37417582211059, 22.57004614740076], [88.37457590056732, 22.56924145954904], [88.37488912201628, 22.568404226565626], [88.37511247142706, 22.567542511898576], [88.37524379945957, 22.566664614623644], [88.37528184310054, 22.565778989508487]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [88.3554773620876, 22.596178277367898, 88.37493139255066, 22.614240912143913], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[88.37493139255066, 22.60512657423555], [88.37487575913575, 22.60424175506977], [88.37472698767208, 22.603366259318076], [88.37448651258607, 22.602508518146543], [88.3741566513023, 22.601676791594876], [88.37374058186724, 22.600879089046146], [88.37324231

# %%
# Merging the buffers into a single polygon
merged_polygon = buffer_1km.unary_union

# %%
# Creating a new map for visualizing the merged polygon
merged_polygon_map = folium.Map(location=[y_avg, x_avg], tiles='CartoDB positron', zoom_start=11)

# %%
# Converting the merged polygon feature into a GeoPandas geoseries with the projected CRS,...
# reprojecting the geoseries to a Geographic CRS for visualization on map,...
# and then converting it to a geojson object to add to the map

merged_polygon_geoj = gpd.GeoSeries(merged_polygon, crs='EPSG:32645').to_crs('EPSG:4326').to_json()
merged_polygon_geoj = folium.GeoJson(data=merged_polygon_geoj)
merged_polygon_geoj.add_to(merged_polygon_map)

merged_polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b799308502b6ebc4f9db1ce0918b4cb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b799308502b6ebc4f9db1ce0918b4cb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b799308502b6ebc4f9db1ce0918b4cb6 = L.map(
#                 &quot;map_b799308502b6ebc4f9db1ce0918b4cb6&quot;,
#                 {
#                     center: [22.557588239285714, 88.37491196052135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b34b1c91f7ecfcdd88ed3a680cf569c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b799308502b6ebc4f9db1ce0918b4cb6);
#
#
#
#         function geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_688e9ed9985d3263ca07ebaeb8d3faaa = L.geoJson(null, {
#                 onEachFeature: geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_onEachFeature,
#
#         });
#
#         function geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_add (data) {
#             geo_json_688e9ed9985d3263ca07ebaeb8d3faaa
#                 .addData(data)
#                 .addTo(map_b799308502b6ebc4f9db1ce0918b4cb6);
#         }
#             geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_add({&quot;bbox&quot;: [88.33672815470287, 22.464838617892287, 88.41237105683211, 22.618782063760488], &quot;features&quot;: [{&quot;bbox&quot;: [88.33672815470287, 22.464838617892287, 88.41237105683211, 22.618782063760488], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[88.3712418535751, 22.471169594933325], [88.37091236872267, 22.470337832050916], [88.37049675447138, 22.469540087957984], [88.36999901444166, 22.46878404467354], [88.36942394286652, 22.468076982543668], [88.36877707839264, 22.46742571015718], [88.36806465072509, 22.466836498806106], [88.36729352063013, 22.466315022121154], [88.36647111387394, 22.46586630146208], [88.36560534973296, 22.46549465758792], [88.3647045647634, 22.465203669071258], [88.3637774325628, 22.464996137856147], [88.36283288029438, 22.46487406229056], [88.36188000277598, 22.464838617892287], [88.36092797495877, 22.46489014603339], [88.35998596363581, 22.46502815065165], [88.35906303922813, 22.465251303020946], [88.35816808849557, 22.465557454534792], [88.35730972901023, 22.46594365738048], [88.35649622621419, 22.466406192905307], [88.35573541385838, 22.46694060740268], [88.35503461858711, 22.46754175497449], [88.35440058939363, 22.46820384705792], [88.35383943262563, 22.46892050814117], [88.35335655316622, 22.469684837132505], [88.35295660235755, 22.470489473792814], [88.35264343316946, 22.47132666959321], [88.35242006304621, 22.47218836231589], [88.35228864479107, 22.47306625368101], [88.35225044577115, 22.473951889252394], [88.35230583564517, 22.474836739853046], [88.35245428273505, 22.47571228370661], [88.35269435907875, 22.476570088513668], [88.35302375411827, 22.4774018926722], [88.35343929689361, 22.478199684859455], [88.35393698653111, 22.478955781208164], [88.3545120307343, 22.47966289933301], [88.3551588919084, 22.48031422849335], [88.35587134047518, 22.480903495215344], [88.35664251486519, 22.481425023740425], [88.35746498761, 22.481873790716637], [88.35833083689732, 22.482245473605015], [88.35923172289878, 22.48253649233367], [88.36015896813424, 22.48274404379752], [88.36110364109665, 22.482866128870462], [88.36205664232992, 22.48290157166931], [88.36300879212858, 22.482850030883498], [88.36395091901196, 22.48271200306116], [88.36487394811805, 22.482488817820144], [88.3657689886635, 22.48218262503016], [88.3666274196248, 22.48179637409016], [88.36744097281306, 22.48133378550107], [88.36820181254079, 22.480799315008706], [88.36890261111184, 22.480198110663057], [88.3695366194061, 22.479535963208704], [88.37009773187906, 22.478819250285326], [88.37058054534982, 22.47805487497686], [88.37098041101216, 22.477250199302333], [88.37129347916836, 22.47641297328995], [88.37151673625674, 22.475551260318525], [88.37164803381789, 22.47467335944605], [88.37168610912296, 22.473787725474082], [88.37163059726748, 22.472902887518146], [88.3714820346172, 22.472027366868662], [88.3712418535751, 22.471169594933325]]], [[[88.37262001379638, 22.502073051428493], [88.3722042846911, 22.50127532001059], [88.37170641219564, 22.500519291019323], [88.37113119182, 22.499812244661957], [88.37048416364453, 22.49916098937412], [88.3697715589509, 22.498571796281908], [88.36900024020967, 22.498050338838926], [88.36817763500264, 22.49760163821846], [88.36731166451564, 22.497230014985504], [88.36641066728991, 22.496939047512964], [88.36548331896455, 22.496731537541557], [88.36453854878118, 22.49660948321417], [88.3635854536532, 22.49657405984386], [88.36263321062428, 22

# %%
# Loading the OSM geopackage file consisting of a points layer of the restaurants in Kolkata 

data_pkg_path = 'data'
filename = 'kolkata_restaurants.gpkg'
path = os.path.join(data_pkg_path, filename)

# Getting the restaurants vector layer as a GeoPandas geodataframe
restaurants_gdf = gpd.read_file(path, layer='kolkata_restaurants')

restaurants_gdf.head()
# Out:
#        full_id      osm_id osm_type     amenity         cuisine          name  \
# 0  n1783122342  1783122342     node  restaurant          indian         Dhaba
# 1  n1833168504  1833168504     node  restaurant          indian   Banana Leaf
# 2  n1833181230  1833181230     node  restaurant  chinese;indian     Bar-B-Que
# 3  n2234881738  2234881738     node  restaurant                  Oh! Calcutta
# 4  n2283710597  2283710597     node  restaurant                       Big Max
#
#   addr:postcode                 addr:street      alt_name  \
# 0
# 1      7000 026  73 & 75 Rash Behari Avenue  Komala Vilas
# 2                               Park Street
# 3        700020                  Elgin Road
# 4        700071               Russel Street
#
#                                     website  ... name:es alcohol  \
# 0                                            ...
# 1  http://www.bananaleaf.in/restaurant.html  ...
# 2                                            ...
# 3             https://www.speciality.co.in/  ...
# 4                                            ...
#
#   brand:wikipedia:pa brand:wikipedia:ur contact:phone contact:website  \
# 0
# 1
# 2
# 3
# 4
#
#   official_name diet:healthy opening_hours:covid19                   geometry
# 0                                                   POINT (88.36579 22.52822)
# 1                                                   POINT (88.34932 22.51700)
# 2                                                   POINT (88.35263 22.55308)
# 3                                                   POINT (88.35122 22.53806)
# 4                                                   POINT (88.35111 22.55377)
#
# [5 rows x 57 columns]

# %%
# Adding the restaurants to the merged plygon map

restaurants_gdf.apply(lambda restaurant:folium.Circle(radius=30, 
                                                      location=[restaurant['geometry'].y, restaurant['geometry'].x], 
                                                      popup=restaurant['name'], 
                                                      color='green', 
                                                      fill=True, 
                                                      fill_opacity=0.5
                                                     ).add_to(merged_polygon_map), axis=1)

merged_polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b799308502b6ebc4f9db1ce0918b4cb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b799308502b6ebc4f9db1ce0918b4cb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b799308502b6ebc4f9db1ce0918b4cb6 = L.map(
#                 &quot;map_b799308502b6ebc4f9db1ce0918b4cb6&quot;,
#                 {
#                     center: [22.557588239285714, 88.37491196052135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b34b1c91f7ecfcdd88ed3a680cf569c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b799308502b6ebc4f9db1ce0918b4cb6);
#
#
#
#         function geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_688e9ed9985d3263ca07ebaeb8d3faaa = L.geoJson(null, {
#                 onEachFeature: geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_onEachFeature,
#
#         });
#
#         function geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_add (data) {
#             geo_json_688e9ed9985d3263ca07ebaeb8d3faaa
#                 .addData(data)
#                 .addTo(map_b799308502b6ebc4f9db1ce0918b4cb6);
#         }
#             geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_add({&quot;bbox&quot;: [88.33672815470287, 22.464838617892287, 88.41237105683211, 22.618782063760488], &quot;features&quot;: [{&quot;bbox&quot;: [88.33672815470287, 22.464838617892287, 88.41237105683211, 22.618782063760488], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[88.3712418535751, 22.471169594933325], [88.37091236872267, 22.470337832050916], [88.37049675447138, 22.469540087957984], [88.36999901444166, 22.46878404467354], [88.36942394286652, 22.468076982543668], [88.36877707839264, 22.46742571015718], [88.36806465072509, 22.466836498806106], [88.36729352063013, 22.466315022121154], [88.36647111387394, 22.46586630146208], [88.36560534973296, 22.46549465758792], [88.3647045647634, 22.465203669071258], [88.3637774325628, 22.464996137856147], [88.36283288029438, 22.46487406229056], [88.36188000277598, 22.464838617892287], [88.36092797495877, 22.46489014603339], [88.35998596363581, 22.46502815065165], [88.35906303922813, 22.465251303020946], [88.35816808849557, 22.465557454534792], [88.35730972901023, 22.46594365738048], [88.35649622621419, 22.466406192905307], [88.35573541385838, 22.46694060740268], [88.35503461858711, 22.46754175497449], [88.35440058939363, 22.46820384705792], [88.35383943262563, 22.46892050814117], [88.35335655316622, 22.469684837132505], [88.35295660235755, 22.470489473792814], [88.35264343316946, 22.47132666959321], [88.35242006304621, 22.47218836231589], [88.35228864479107, 22.47306625368101], [88.35225044577115, 22.473951889252394], [88.35230583564517, 22.474836739853046], [88.35245428273505, 22.47571228370661], [88.35269435907875, 22.476570088513668], [88.35302375411827, 22.4774018926722], [88.35343929689361, 22.478199684859455], [88.35393698653111, 22.478955781208164], [88.3545120307343, 22.47966289933301], [88.3551588919084, 22.48031422849335], [88.35587134047518, 22.480903495215344], [88.35664251486519, 22.481425023740425], [88.35746498761, 22.481873790716637], [88.35833083689732, 22.482245473605015], [88.35923172289878, 22.48253649233367], [88.36015896813424, 22.48274404379752], [88.36110364109665, 22.482866128870462], [88.36205664232992, 22.48290157166931], [88.36300879212858, 22.482850030883498], [88.36395091901196, 22.48271200306116], [88.36487394811805, 22.482488817820144], [88.3657689886635, 22.48218262503016], [88.3666274196248, 22.48179637409016], [88.36744097281306, 22.48133378550107], [88.36820181254079, 22.480799315008706], [88.36890261111184, 22.480198110663057], [88.3695366194061, 22.479535963208704], [88.37009773187906, 22.478819250285326], [88.37058054534982, 22.47805487497686], [88.37098041101216, 22.477250199302333], [88.37129347916836, 22.47641297328995], [88.37151673625674, 22.475551260318525], [88.37164803381789, 22.47467335944605], [88.37168610912296, 22.473787725474082], [88.37163059726748, 22.472902887518146], [88.3714820346172, 22.472027366868662], [88.3712418535751, 22.471169594933325]]], [[[88.37262001379638, 22.502073051428493], [88.3722042846911, 22.50127532001059], [88.37170641219564, 22.500519291019323], [88.37113119182, 22.499812244661957], [88.37048416364453, 22.49916098937412], [88.3697715589509, 22.498571796281908], [88.36900024020967, 22.498050338838926], [88.36817763500264, 22.49760163821846], [88.36731166451564, 22.497230014985504], [88.36641066728991, 22.496939047512964], [88.36548331896455, 22.496731537541557], [88.36453854878118, 22.49660948321417], [88.3635854536532, 22.49657405984386], [88.36263321062428, 22

# %%
# Reprojecting the restaurants geodataframe to the projected CRS - WGS 84 UTM 45N

restaurants_gdf_reprojected = restaurants_gdf.to_crs('EPSG:32645')
restaurants_gdf_reprojected.head()
# Out:
#        full_id      osm_id osm_type     amenity         cuisine          name  \
# 0  n1783122342  1783122342     node  restaurant          indian         Dhaba
# 1  n1833168504  1833168504     node  restaurant          indian   Banana Leaf
# 2  n1833181230  1833181230     node  restaurant  chinese;indian     Bar-B-Que
# 3  n2234881738  2234881738     node  restaurant                  Oh! Calcutta
# 4  n2283710597  2283710597     node  restaurant                       Big Max
#
#   addr:postcode                 addr:street      alt_name  \
# 0
# 1      7000 026  73 & 75 Rash Behari Avenue  Komala Vilas
# 2                               Park Street
# 3        700020                  Elgin Road
# 4        700071               Russel Street
#
#                                     website  ... name:es alcohol  \
# 0                                            ...
# 1  http://www.bananaleaf.in/restaurant.html  ...
# 2                                            ...
# 3             https://www.speciality.co.in/  ...
# 4                                            ...
#
#   brand:wikipedia:pa brand:wikipedia:ur contact:phone contact:website  \
# 0
# 1
# 2
# 3
# 4
#
#   official_name diet:healthy opening_hours:covid19  \
# 0
# 1
# 2
# 3
# 4
#
#                          geometry
# 0  POINT (640459.336 2491936.453)
# 1  POINT (638776.467 2490679.769)
# 2  POINT (639080.848 2494677.150)
# 3  POINT (638950.703 2493012.947)
# 4  POINT (638924.022 2494751.986)
#
# [5 rows x 57 columns]

# %%
# Generating a Pandas series of boolean values indicating which restaurants intersect the merged polygon
bool_series = restaurants_gdf_reprojected['geometry'].intersects(merged_polygon)

# Using the boolean series to filter out the required restaurants from the restaurants geodataframe
restaurants_within_1km = restaurants_gdf_reprojected[bool_series]

# Finally, we have the retaurants located within 1 km of the places to visit
restaurants_within_1km.head()
# Out:
#         full_id      osm_id osm_type     amenity cuisine         name  \
# 0   n1783122342  1783122342     node  restaurant  indian        Dhaba
# 1   n1833168504  1833168504     node  restaurant  indian  Banana Leaf
# 8   n2560440346  2560440346     node  restaurant  indian       Aminia
# 13  n3051834901  3051834901     node  restaurant  indian      Kasturi
# 15  n3410845680  3410845680     node  restaurant                Thali
#
#    addr:postcode                 addr:street      alt_name  \
# 0
# 1       7000 026  73 & 75 Rash Behari Avenue  Komala Vilas
# 8
# 13
# 15
#
#                                      website  ... name:es alcohol  \
# 0                                             ...
# 1   http://www.bananaleaf.in/restaurant.html  ...
# 8                                             ...
# 13                                            ...
# 15                                            ...
#
#    brand:wikipedia:pa brand:wikipedia:ur contact:phone contact:website  \
# 0
# 1
# 8
# 13
# 15
#
#    official_name diet:healthy opening_hours:covid19  \
# 0
# 1
# 8
# 13
# 15
#
#                           geometry
# 0   POINT (640459.336 2491936.453)
# 1   POINT (638776.467 2490679.769)
# 8   POINT (640582.019 2490675.157)
# 13  POINT (640616.880 2491828.707)
# 15  POINT (642860.491 2490578.976)
#
# [5 rows x 57 columns]

# %%
# Reprojecting the filtered restaurants geodataframe to the Geographic CRS for visualization on map
restaurants_within_1km = restaurants_within_1km.to_crs('EPSG:4326')

# %%
# Adding the filtered restaurants to the merged polygon map with yellow color...
# to compare with the rest of the restaurants in green color

restaurants_within_1km.apply(lambda restaurant:folium.Circle(radius=30, 
                                                             location=[restaurant['geometry'].y, restaurant['geometry'].x], 
                                                             popup=restaurant['name'], 
                                                             color='yellow', 
                                                             fill=True, 
                                                             fill_opacity=0.8).add_to(merged_polygon_map), axis=1)

merged_polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b799308502b6ebc4f9db1ce0918b4cb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b799308502b6ebc4f9db1ce0918b4cb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b799308502b6ebc4f9db1ce0918b4cb6 = L.map(
#                 &quot;map_b799308502b6ebc4f9db1ce0918b4cb6&quot;,
#                 {
#                     center: [22.557588239285714, 88.37491196052135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b34b1c91f7ecfcdd88ed3a680cf569c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b799308502b6ebc4f9db1ce0918b4cb6);
#
#
#
#         function geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_688e9ed9985d3263ca07ebaeb8d3faaa = L.geoJson(null, {
#                 onEachFeature: geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_onEachFeature,
#
#         });
#
#         function geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_add (data) {
#             geo_json_688e9ed9985d3263ca07ebaeb8d3faaa
#                 .addData(data)
#                 .addTo(map_b799308502b6ebc4f9db1ce0918b4cb6);
#         }
#             geo_json_688e9ed9985d3263ca07ebaeb8d3faaa_add({&quot;bbox&quot;: [88.33672815470287, 22.464838617892287, 88.41237105683211, 22.618782063760488], &quot;features&quot;: [{&quot;bbox&quot;: [88.33672815470287, 22.464838617892287, 88.41237105683211, 22.618782063760488], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[88.3712418535751, 22.471169594933325], [88.37091236872267, 22.470337832050916], [88.37049675447138, 22.469540087957984], [88.36999901444166, 22.46878404467354], [88.36942394286652, 22.468076982543668], [88.36877707839264, 22.46742571015718], [88.36806465072509, 22.466836498806106], [88.36729352063013, 22.466315022121154], [88.36647111387394, 22.46586630146208], [88.36560534973296, 22.46549465758792], [88.3647045647634, 22.465203669071258], [88.3637774325628, 22.464996137856147], [88.36283288029438, 22.46487406229056], [88.36188000277598, 22.464838617892287], [88.36092797495877, 22.46489014603339], [88.35998596363581, 22.46502815065165], [88.35906303922813, 22.465251303020946], [88.35816808849557, 22.465557454534792], [88.35730972901023, 22.46594365738048], [88.35649622621419, 22.466406192905307], [88.35573541385838, 22.46694060740268], [88.35503461858711, 22.46754175497449], [88.35440058939363, 22.46820384705792], [88.35383943262563, 22.46892050814117], [88.35335655316622, 22.469684837132505], [88.35295660235755, 22.470489473792814], [88.35264343316946, 22.47132666959321], [88.35242006304621, 22.47218836231589], [88.35228864479107, 22.47306625368101], [88.35225044577115, 22.473951889252394], [88.35230583564517, 22.474836739853046], [88.35245428273505, 22.47571228370661], [88.35269435907875, 22.476570088513668], [88.35302375411827, 22.4774018926722], [88.35343929689361, 22.478199684859455], [88.35393698653111, 22.478955781208164], [88.3545120307343, 22.47966289933301], [88.3551588919084, 22.48031422849335], [88.35587134047518, 22.480903495215344], [88.35664251486519, 22.481425023740425], [88.35746498761, 22.481873790716637], [88.35833083689732, 22.482245473605015], [88.35923172289878, 22.48253649233367], [88.36015896813424, 22.48274404379752], [88.36110364109665, 22.482866128870462], [88.36205664232992, 22.48290157166931], [88.36300879212858, 22.482850030883498], [88.36395091901196, 22.48271200306116], [88.36487394811805, 22.482488817820144], [88.3657689886635, 22.48218262503016], [88.3666274196248, 22.48179637409016], [88.36744097281306, 22.48133378550107], [88.36820181254079, 22.480799315008706], [88.36890261111184, 22.480198110663057], [88.3695366194061, 22.479535963208704], [88.37009773187906, 22.478819250285326], [88.37058054534982, 22.47805487497686], [88.37098041101216, 22.477250199302333], [88.37129347916836, 22.47641297328995], [88.37151673625674, 22.475551260318525], [88.37164803381789, 22.47467335944605], [88.37168610912296, 22.473787725474082], [88.37163059726748, 22.472902887518146], [88.3714820346172, 22.472027366868662], [88.3712418535751, 22.471169594933325]]], [[[88.37262001379638, 22.502073051428493], [88.3722042846911, 22.50127532001059], [88.37170641219564, 22.500519291019323], [88.37113119182, 22.499812244661957], [88.37048416364453, 22.49916098937412], [88.3697715589509, 22.498571796281908], [88.36900024020967, 22.498050338838926], [88.36817763500264, 22.49760163821846], [88.36731166451564, 22.497230014985504], [88.36641066728991, 22.496939047512964], [88.36548331896455, 22.496731537541557], [88.36453854878118, 22.49660948321417], [88.3635854536532, 22.49657405984386], [88.36263321062428, 22

# %% [markdown]
# ***
# ### Putting it all together
#
# Finally! We are done with our spatial analysis. Now, it's time to visulaize the Durga Puja places to visit, the optimum route to travel from my home to all these locations, and the restaurants I can reach within 1 km of these places - all together on our Kolkata map.

# %%
# Adding the filtered restaurants to the Kolkata map

restaurants_within_1km.apply(lambda restaurant:folium.Circle(radius=30, 
                                                             location=[restaurant['geometry'].y, restaurant['geometry'].x], 
                                                             popup=restaurant['name'], 
                                                             color='green', 
                                                             fill=True, 
                                                             fill_color='yellow', 
                                                             fill_opacity=0.5).add_to(kolkata_map), axis=1)

# Our final map is ready!
kolkata_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad66ea6cea0b3605b880d9ca42798bb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad66ea6cea0b3605b880d9ca42798bb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ad66ea6cea0b3605b880d9ca42798bb6 = L.map(
#                 &quot;map_ad66ea6cea0b3605b880d9ca42798bb6&quot;,
#                 {
#                     center: [22.557588239285714, 88.37491196052135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5888eef4f6b93f0534953e3ad111b05 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var marker_95dc3319fec329abc913cb053c8fb239 = L.marker(
#                 [22.707052, 88.463047],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_d892f8ffaeec0f67a9793104fae64b89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_95dc3319fec329abc913cb053c8fb239.setIcon(icon_d892f8ffaeec0f67a9793104fae64b89);
#
#
#         var popup_04396997bcd58604b715f933cd6269a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4f7344f6c5ca43b49e2bee0cba10dc97 = $(`&lt;div id=&quot;html_4f7344f6c5ca43b49e2bee0cba10dc97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Home&lt;/div&gt;`)[0];
#             popup_04396997bcd58604b715f933cd6269a2.setContent(html_4f7344f6c5ca43b49e2bee0cba10dc97);
#
#
#         marker_95dc3319fec329abc913cb053c8fb239.bindPopup(popup_04396997bcd58604b715f933cd6269a2)
#         ;
#
#
#
#
#             var marker_b6c15a092053ee67daf9f5d135b728ab = L.marker(
#                 [22.5658619, 88.36555761435561],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_b9e7c96829691c7e6a13c9ea30ef2d12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6c15a092053ee67daf9f5d135b728ab.setIcon(icon_b9e7c96829691c7e6a13c9ea30ef2d12);
#
#
#         var popup_e8d7b2bbcfcb172de7aadc5d1ce3e412 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1f881c85601eda3d54328df651262df6 = $(`&lt;div id=&quot;html_1f881c85601eda3d54328df651262df6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santosh Mitra Square&lt;/div&gt;`)[0];
#             popup_e8d7b2bbcfcb172de7aadc5d1ce3e412.setContent(html_1f881c85601eda3d54328df651262df6);
#
#
#         marker_b6c15a092053ee67daf9f5d135b728ab.bindPopup(popup_e8d7b2bbcfcb172de7aadc5d1ce3e412)
#         ;
#
#
#
#
#             var marker_c78fde0035f3f6b6ffda1c71f0e77a1a = L.marker(
#                 [22.6052096, 88.3652044],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_e4bd21c951744caf54bc43f91fa21c84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c78fde0035f3f6b6ffda1c71f0e77a1a.setIcon(icon_e4bd21c951744caf54bc43f91fa21c84);
#
#
#         var popup_85e8820250edb2e92980473e0459d93a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6f30da73fb21e4c573e5120bb158534c = $(`&lt;div id=&quot;html_6f30da73fb21e4c573e5120bb158534c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bagbazar&lt;/div&gt;`)[0];
#             popup_85e8820250edb2e92980473e0459d93a.setContent(html_6f30da73fb21e4c573e5120bb158534c);
#
#
#         marker_c78fde0035f3f6b6ffda1c71f0e77a1a.bindPopup(popup_85e8820250edb2e92980473e0459d93a)
#         ;
#
#
#
#
#             var marker_f712093ddc6f83f937e3a08eb432fb16 = L.marker(
#                 [22.57465335, 88.36390478535333],
#                 {}
#             ).addTo(map_ad66ea6cea0b3605b880d9ca42798bb6);
#
#
#             var icon_458e2cba1f7c844e8ee300e89293031f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;
